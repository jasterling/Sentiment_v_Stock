# %% [markdown]
# # Kick-Off

# %%
# %pylab inline
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import operator
import pickle
from pprint import pprint
import re
import string
import seaborn as sns
sns.set(color_codes=True)

# Import all of the sklearn stuff
import sklearn
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans, MiniBatchKMeans
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.decomposition import NMF, LatentDirichletAllocation

# Sentiment
from textblob import TextBlob
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Tokenize
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.lancaster import LancasterStemmer
#from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords


# Not being used
# gensim modules
# from gensim.parsing.preprocessing import STOPWORDS
# from gensim.models import TfidfModel, LsiModel
# from gensim.models.ldamodel import LdaModel
# from gensim import corpora
# from gensim import matutils
# # from gensim.utils import simple_preprocess

# # misc modules
# import pyLDAvis.gensim as gensimvis
# import pyLDAvis
# from sklearn.cluster import KMeans
# from sklearn.decomposition import NMF, LatentDirichletAllocation
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/jas/anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# # Twitter - Topic Modeling (no sentiment - nothing worthy of reading)

# %% [markdown]
# ### LDA - Topic Modeling with SKLearn

# %%
# df_pp = pd.read_csv('tweet_data/amzn_tweets5.csv')
# df_pp.drop(columns=['Unnamed: 0', 'place'], axis=1, inplace=True)
# tweets = [x for x in df_pp['text']]

# %%
# read in bigger data...
df = pd.read_pickle('tweet_data/tweet_master.pkl')
tweets = [x for x in df['text']]
clean_tweets = [x for x in tweets if str(x) != 'nan']
len(tweets)
# Out:
# 984737

# %%
# tweets[20385:20400] # for some reason returned a couple 'nan's

# %%
def clean_links(tweet):
    no_link = re.sub(r'http\S+', '', tweet)
    no_mention = re.sub(r'@\S+', '', no_link)
    no_emoji = re.sub(r'[^\w\s,]', '', no_mention)
    return (no_emoji)

# %%
clean_list = []
for t in clean_tweets:
    clean_list.append(clean_links(t))

clean_list[:10]
# Out:
# ['Jah Rastafari Crest Samsung Case  Samsung Galaxy S8 Saytoons Trenton Denver Brooklyn LosAngeles  via ',
#  'RT  This book is humorous, creepy, scary and suspenseful all in one\n\nWɪᴛᴄʜ Hᴜɴᴛᴇʀ Iɴᴛᴏ ᴛʜᴇ Oᴜᴛsɪᴅᴇ\n\nurbanfantasy Kind',
#  'RT  久々に本を一冊読み切りそうですこの本は著者が自らの経験から感じたことや思われたことを着色せず語られているので読みやすく分かりやすく今の時代と此れからの生き方を考える上では必読おススメです 守先生亀田女史甲野先生ご縁結びありがとうござい',
#  'ULATREE Women Criss Cross Front Tops Short Sl by ULATREE  via  ',
#  'RT  Do you like dialogues as powerful as dhai kilo ka haath Or get senti when some says Mere pass maa hai Tell us which B',
#  '  そーなんですねその方が安全かなぁ\n都心もヤバいですよ家の近所本屋さんないしAmazonか',
#  ' Amazonさんで19,000円しなかったと思う',
#  '日々の疲れは音楽で癒してｗΨAmazon\u3000ミュージックヒーリングベストセラー\u3000',
#  'USA 45 off, 44 Stars Solar  Motion Sensor Lights Outdoor 100 Led Super Bright W Details Its brightness gre ',
#  'RT  Y abrió los ojos, entornados, un halo de luz le llamaba, de una pantalla miles de amigos le saludaban, todos en su manob']

# %%
# only basic term frequency can be considered with LDA because it defines 
# its own PROBABALISTIC determination of topics / grouping / etc.

n_components = 10

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=3,
                                ngram_range=(1,3),
                                max_features=1000,
                                stop_words='english')
tf = tf_vectorizer.fit_transform(clean_list)

# define model (lda) and model parameters, fit model to vectorized data
lda = LatentDirichletAllocation(n_components=n_components, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx), " ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
#         print (" ".join([feature_names[i]
#                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, vocab, n_components)
# Out:
# Topic 0: oneplus6 thespeedyouneed buy oneplus6 buy oneplus6 thespeedyouneed starts buy oneplus6 starts buy sale starts buy new google best
# Topic 1: rt amazon just today single asmsg iartg single day rt rt away
# Topic 2: amazon rt oneplus6 thespeedyouneed rt amazon time bezos jeff jeff bezos win prime
# Topic 3: amp starts rt like check police amazons trump need billboard
# Topic 4: sale sale starts rt recognition facial recognition free stream kindle selling romance
# Topic 5: rt book read day available books great rely make threatened
# Topic 6: buy rt love facial music fake fake love series story million
# Topic 7: aclu things youtube spotify apple play amazon tidal party later love mass stream later youtube spotify later youtube mass stream mass stream party
# Topic 8: amazon life workers founder amazon workers day amazon 275 275 million bezos wealth increases
# Topic 9: amazon apple play itunes spotify google play apple music rt tidal 100

# %%
lda.perplexity(tf)
# Out:
# 337.5130784636723

# %%
# running this, this displays the document and its probabilities (this is kind of stuff where you
# need to know how the data is transforming and crunch behind the scenes. Don't need to prove it, just 
# follow it.)
x = lda.transform(tf) # this gives the various "groups"... see below when PCA transformed
y = clean_target.target # this is for color below. Explains which newsgroup it is from.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-83f8e599cecc> in <module>()
#       3 # follow it.)
#       4 x = lda.transform(tf) # this gives the various "groups"... see below when PCA transformed
# ----> 5 y = clean_target.target # this is for color below. Explains which newsgroup it is from.
#
# NameError: name 'clean_target' is not defined

# %% [markdown]
# ##### Visualize the matrix...

# %%
from sklearn.decomposition import PCA

pca = PCA(4).fit_transform(x) #as it is, it is the first and second principle component of being in one of the 
# topics defined previously #np.log(x) also an option for displaying data
pca0 = pca[:,0]
pca1 = pca[:,1]
pca2 = pca[:,2]
pca3 = pca[:,3]

# %%
pca0
# Out:
# array([ 0.16851186, -0.48105086, -0.44045444,  0.60108196, -0.372791  ,
#         0.42531003,  0.19425575, -0.41105991, -0.37277157,  0.19752219,
#         0.6628814 , -0.5622492 , -0.21462997, -0.55322988,  0.6731808 ,
#        -0.23746768, -0.37277314, -0.5274462 ,  0.200428  ,  0.60106978,
#         0.184038  ,  0.20890651,  0.55301493,  0.20890651,  0.1930907 ,
#        -0.55322956, -0.57577908, -0.56224327,  0.66288054,  0.60106822,
#        -0.56962439,  0.67317804, -0.21904771, -0.55321788,  0.19886788,
#        -0.48104382,  0.18848628,  0.46911528,  0.45686364,  0.62992339,
#        -0.54194515,  0.6010725 , -0.57578314,  0.19441035,  0.22044763,
#        -0.44045677,  0.66286471,  0.64914254,  0.60108542,  0.6299146 ,
#         0.6010725 ,  0.22044763, -0.37862941,  0.62992338,  0.66288221,
#         0.19425451, -0.5081074 , -0.52744443,  0.55300519,  0.00505363,
#         0.19706813,  0.10509325, -0.50811775, -0.01504563,  0.35023952,
#         0.20142553, -0.48104998, -0.44041474,  0.22044763,  0.20142553,
#         0.35858554, -0.56225112, -0.48103008, -0.5757796 , -0.44043499,
#         0.32886418, -0.55322786,  0.19814919,  0.20142553,  0.67318139,
#        -0.37277851,  0.45689236,  0.553015  , -0.17316113,  0.19694537,
#        -0.5274462 , -0.56225338, -0.44044779,  0.22044763,  0.17660081,
#         0.19736597, -0.52745413,  0.22021662,  0.55302045, -0.54195217,
#        -0.37279095,  0.18290026, -0.56224084,  0.42510928,  0.19724908,
#        -0.44044274,  0.62992338,  0.19694537, -0.52744944,  0.12638858,
#        -0.50811786,  0.72391712, -0.10618418, -0.44044531,  0.20157497,
#         0.19886788, -0.08054544, -0.48104684,  0.18812149,  0.16851186,
#        -0.54195149,  0.19694537,  0.22044763,  0.64915049,  0.67317949,
#         0.19303001,  0.6731747 ,  0.6010721 , -0.22272257, -0.52744139,
#         0.5530075 ,  0.20142553, -0.50811519, -0.44043511,  0.20030342,
#         0.6299205 , -0.23746849, -0.48103638,  0.23624348,  0.68118889,
#         0.72391712,  0.19694537,  0.62992336, -0.09837967,  0.17906575,
#         0.38196904, -0.44044958,  0.22029951,  0.20142553,  0.60107715,
#        -0.52744816,  0.60106228,  0.64914021,  0.19694537,  0.19182001,
#         0.68119025,  0.17659517,  0.12392517, -0.42954659,  0.18238595,
#         0.45686364, -0.23216467,  0.5529809 , -0.48104235,  0.55301498,
#         0.649142  , -0.54193906,  0.64914814,  0.60107769,  0.19303007,
#         0.45686364,  0.55301236,  0.67318201,  0.2034251 ,  0.60108238,
#         0.20142553,  0.19379102, -0.5274482 ,  0.19450847,  0.72391712,
#        -0.54194058,  0.62992023, -0.2374513 ,  0.22044763,  0.66286784,
#         0.19626392, -0.50811594,  0.57184649, -0.57578314,  0.19373038,
#         0.16851186, -0.44041235, -0.58545074,  0.20142553, -0.5893103 ,
#        -0.37277545,  0.45686364,  0.20157497,  0.72309532, -0.42516608,
#         0.72220821, -0.44044959,  0.09416459,  0.05656064,  0.1010849 ,
#        -0.37278146, -0.55322678, -0.48104644, -0.3019255 ,  0.66287249,
#         0.64914834,  0.16075322,  0.16851186,  0.2192028 ,  0.6628685 ,
#         0.22044763,  0.22044763,  0.68119199, -0.30414955,  0.20042726,
#        -0.52743927, -0.37277386, -0.48104599, -0.62025048,  0.20142553,
#         0.60107163, -0.57578373,  0.45686364, -0.57578373,  0.20142553,
#        -0.52744693, -0.48104644, -0.52744576,  0.67317731, -0.44044452,
#         0.66285921, -0.52744234,  0.17906573, -0.37279085,  0.66288054,
#        -0.23746747, -0.37276826, -0.48104681, -0.50812089,  0.62991374,
#         0.64914776,  0.21992296, -0.562247  ,  0.649148  ,  0.19812645,
#        -0.5081145 , -0.48103964,  0.1937304 ,  0.20142553,  0.19886788,
#        -0.37277239, -0.44045316,  0.16851186, -0.50810368, -0.55322843,
#         0.45689494, -0.21016195,  0.22021662, -0.52745343,  0.66288219,
#        -0.58098792, -0.50811961,  0.60107228,  0.22044763, -0.58098952,
#         0.68119278,  0.34778085,  0.45686364,  0.45686364,  0.22021662,
#         0.68760048, -0.44045256,  0.20142553, -0.44045616, -0.48104166,
#        -0.54195038, -0.56225338, -0.5081127 ,  0.19736963,  0.18321857,
#        -0.44045361, -0.2374513 ,  0.55301995,  0.72309532,  0.55840056,
#        -0.55322226,  0.19302956, -0.50811105, -0.52744584, -0.2374513 ,
#         0.19626392,  0.60108341, -0.3727581 , -0.37279553,  0.21158544,
#         0.19839525,  0.19209981, -0.44943824, -0.09687021, -0.5854487 ,
#        -0.60285091, -0.55322848, -0.5419498 ,  0.18321925,  0.19736963,
#         0.64914418, -0.48103497,  0.28749852,  0.60108338, -0.55322135,
#        -0.23746768, -0.5081029 , -0.37279108, -0.48105025, -0.37277184,
#        -0.52745357,  0.22044763,  0.18146135,  0.19722249,  0.19441255,
#         0.673162  ,  0.55302074, -0.50811638, -0.57577908,  0.19736963,
#         0.27981434,  0.20142553, -0.52744031,  0.72309532, -0.52743783,
#         0.60107766,  0.02296878, -0.5081115 , -0.48104911, -0.44044786,
#         0.19834746, -0.37007921,  0.19736963, -0.37277547,  0.55301333,
#         0.19205169, -0.47823716,  0.19799015,  0.18415964, -0.08961424,
#        -0.55322226,  0.64913532, -0.30309421, -0.54195177, -0.5419498 ,
#        -0.35338137,  0.62991285, -0.44044786,  0.19736963,  0.64914293,
#         0.19886788,  0.20142553,  0.45688524, -0.52745208, -0.5419504 ,
#         0.34707875,  0.22044763, -0.54195117,  0.19839525, -0.48104172,
#        -0.37277053,  0.68119278, -0.5081131 , -0.50810925, -0.33736276,
#         0.60108079,  0.19799015, -0.09065923, -0.48105517,  0.66287487,
#        -0.50809594,  0.19736963, -0.44042884, -0.44045425, -0.30928078,
#        -0.52745401,  0.19466356,  0.20142553, -0.48105151,  0.19677224,
#        -0.55322353,  0.67317864,  0.68118831,  0.17906575,  0.19886788,
#         0.22044763,  0.22044763,  0.20142553, -0.48104854,  0.64914437,
#         0.07849571, -0.58931468,  0.18065185, -0.48105025,  0.05469529,
#         0.60108287,  0.51375573, -0.52745207, -0.44044706, -0.56224943,
#         0.30109133, -0.40540767,  0.20142553,  0.67316069,  0.44488723,
#        -0.37278669, -0.38792457,  0.67316069, -0.37278503, -0.5419415 ,
#         0.16851186,  0.18238645,  0.21937833, -0.59269896, -0.44043461,
#        -0.58931468,  0.3217806 ,  0.45686364, -0.47215107, -0.44943824,
#         0.19799015, -0.56224774,  0.62992169, -0.52744585,  0.19720152,
#        -0.5419452 ,  0.60108712,  0.68119025,  0.17906575,  0.05073073,
#        -0.44044786, -0.48104479, -0.50811974, -0.56225112, -0.48105246,
#         0.67318049, -0.50812053, -0.44045553,  0.19886788, -0.44043141,
#        -0.39833879, -0.23746715,  0.19843933,  0.45688639,  0.18325208,
#        -0.56224752,  0.20132901, -0.31886897,  0.60107382,  0.19373027,
#         0.19720152, -0.52745299, -0.52745007,  0.68119188,  0.45688708,
#        -0.48105448,  0.68759976,  0.21953658,  0.687601  ,  0.55300437,
#         0.22021662, -0.481056  ,  0.49250772, -0.54194367,  0.16851186,
#        -0.5081053 ,  0.629916  , -0.55322805, -0.54195035,  0.25330969,
#         0.67317792,  0.67316069, -0.47682339,  0.07881415,  0.66287525,
#         0.20042747, -0.48103445,  0.19720152,  0.67317574, -0.23746801,
#         0.16851186, -0.54195038, -0.48104538,  0.20157497, -0.54194633,
#        -0.50811673, -0.48105538,  0.17906575, -0.16473157, -0.48105249,
#         0.66287765,  0.553015  ,  0.19720152,  0.16851186,  0.19548168,
#         0.19886788, -0.44044822, -0.1459606 , -0.5081202 , -0.37279088,
#         0.64914344,  0.6628662 ,  0.20030342, -0.04239279, -0.48105103,
#         0.45686364,  0.19724908,  0.19548168,  0.22044763,  0.19720152,
#        -0.11911099, -0.52745051,  0.19236991, -0.55322805, -0.50811897,
#         0.687601  ,  0.64914776,  0.19548168, -0.44045755,  0.04228899,
#        -0.44044851,  0.4912532 , -0.54195388,  0.22044763, -0.50811603,
#         0.19720152,  0.16851186, -0.55322556,  0.62991164, -0.55322678,
#        -0.40733255,  0.16851186, -0.5081085 ,  0.22021678,  0.22021678,
#        -0.48104894, -0.19414472,  0.22044763,  0.67317637, -0.48104998,
#        -0.17145809,  0.6491399 , -0.23746824,  0.19626392,  0.18373044,
#         0.19544221, -0.37279009, -0.60285091,  0.19814919,  0.17660081,
#        -0.60285091,  0.62992184, -0.58098749, -0.48104525,  0.22044763,
#        -0.37277585,  0.19799015,  0.66287902,  0.19209858, -0.57578346,
#         0.66287739, -0.05226153,  0.62991629, -0.48103598,  0.6491362 ,
#         0.16851186, -0.17496984, -0.36962558,  0.66287174,  0.19210635,
#         0.18200219,  0.51756794, -0.55321614,  0.19308334, -0.23744838,
#         0.5341447 ,  0.19057776,  0.55302106, -0.48105317,  0.36353894,
#        -0.10575099,  0.31488794, -0.5419527 ,  0.16851186,  0.60107509,
#        -0.23745403,  0.22029951, -0.37277157,  0.18321304,  0.45686364,
#         0.19814919,  0.19886788,  0.6628724 ,  0.60107065, -0.54194969,
#        -0.37278005, -0.37279082, -0.48105558, -0.06418481, -0.54194102,
#        -0.508111  ,  0.60108353, -0.60071438,  0.17906575,  0.22044763,
#        -0.5893166 ,  0.55302301,  0.22021662, -0.56224814, -0.44045644,
#         0.14993208,  0.19308477, -0.07594837, -0.54194288,  0.02432693,
#        -0.30188351, -0.48103542, -0.48103368, -0.5419457 ,  0.55299481,
#         0.62990478,  0.43811358, -0.55322556, -0.12788443,  0.22044763,
#        -0.37279019,  0.22021662, -0.54195158, -0.37276966, -0.2374678 ,
#         0.66288038, -0.44045035,  0.16075322,  0.67317204, -0.37278085,
#        -0.48105674, -0.48104798, -0.48104092, -0.55322496,  0.64912984,
#        -0.5081167 ,  0.62992048, -0.55322734, -0.52744699, -0.50812076,
#         0.16851186, -0.37279492, -0.37278037,  0.50156052, -0.1509381 ,
#        -0.23746863, -0.48103739,  0.4130547 ,  0.22021662,  0.45689513,
#        -0.52744655, -0.52744802, -0.44045573,  0.16851186,  0.18325706,
#         0.17930771,  0.66285833,  0.23180484, -0.54194622,  0.64914605,
#        -0.37277563,  0.68118869, -0.54195039, -0.56224943,  0.19814919,
#         0.22044763, -0.37279109, -0.44043915, -0.44045882, -0.5696341 ,
#         0.62991266,  0.22021662,  0.33984392, -0.20315881, -0.23746863,
#        -0.54194274, -0.48105078, -0.5274478 ,  0.19514902, -0.0898094 ,
#         0.18415964,  0.22021662,  0.64914578,  0.19706813,  0.18415964,
#         0.18412109, -0.04456186,  0.64914578, -0.5081124 , -0.54194568,
#         0.20053866, -0.50810898,  0.45686364,  0.64914788, -0.4810416 ,
#        -0.48104644, -0.5081116 ,  0.38607598,  0.17906575, -0.2374513 ,
#         0.37823364,  0.19372984,  0.62991977,  0.19812645,  0.68119051,
#         0.20157497,  0.62452207,  0.55301501,  0.66288009, -0.44044794,
#         0.64914169,  0.18146147, -0.48104545, -0.37278123,  0.60108586,
#         0.19814919, -0.44044981,  0.62991285,  0.19175238, -0.44045625,
#        -0.44044786,  0.45688109,  0.19204911, -0.50811694, -0.55322365,
#         0.60108547, -0.19065171,  0.32199582,  0.6010709 , -0.50810839,
#         0.19195091,  0.19886788,  0.19724908, -0.52744517,  0.62991817,
#         0.60106238,  0.66287785, -0.50810045,  0.22044763, -0.37277157,
#         0.62992112,  0.19706813, -0.50810832,  0.17906573, -0.52745217,
#         0.19886788, -0.2374513 , -0.09454806,  0.1376238 ,  0.51698178,
#         0.45686364,  0.15019459,  0.19886788,  0.68119262, -0.44045274,
#         0.16851186,  0.2034251 , -0.50811724,  0.16851186, -0.50810746,
#         0.19814919, -0.52744862,  0.45688924,  0.45688604,  0.17906573,
#         0.20157497,  0.67318063,  0.18817237,  0.19736597,  0.00551175,
#        -0.44044723,  0.60107982,  0.19719417, -0.48104978,  0.32199582,
#         0.62990562, -0.23746872,  0.45978988, -0.18990657, -0.16250263,
#        -0.16250263,  0.17906573,  0.02173832,  0.62990628,  0.60108338,
#        -0.38724983,  0.64914711, -0.44043539,  0.22044763,  0.20157497,
#        -0.48104531,  0.32199582,  0.19814919, -0.50811532,  0.18238651,
#        -0.37278294, -0.61956823,  0.19886788, -0.56963339,  0.21967851,
#        -0.44044976,  0.19287442, -0.44044738,  0.66287763,  0.67318201,
#        -0.33955651, -0.23892041, -0.2374513 , -0.54194469,  0.51497353,
#         0.66288237, -0.56963249,  0.60105845, -0.44044722, -0.08463156,
#        -0.48104692,  0.18373044, -0.41795819,  0.22021662,  0.18238651,
#        -0.30937034, -0.48105044,  0.6491485 ,  0.19441035, -0.50812169,
#         0.26028827, -0.08635566, -0.61956823,  0.19886788, -0.11907466,
#         0.60108127, -0.55321788,  0.6731771 , -0.4810489 , -0.48104888,
#        -0.56225105,  0.69721103,  0.19812645, -0.48105126, -0.4810494 ,
#        -0.56224615, -0.23746663, -0.61956823,  0.19706813, -0.50811428,
#         0.55302308, -0.23746809, -0.44043728,  0.19814919, -0.48104198,
#         0.19466434,  0.62992061, -0.48104919, -0.37276643,  0.338237  ,
#        -0.26433205,  0.09121424, -0.0858314 ,  0.66288005, -0.50811046,
#        -0.61956823,  0.12963971, -0.30634307, -0.52744443,  0.62991603,
#        -0.2374513 ,  0.66288054, -0.52745055, -0.56224943, -0.56224716,
#         0.45686364, -0.55321744,  0.17906573,  0.32771421, -0.50810844,
#         0.20678439,  0.19210278,  0.19057536, -0.50811014,  0.62992267,
#        -0.48105017, -0.52744382, -0.19399221, -0.54195035, -0.61956823,
#         0.55301335,  0.4568952 ,  0.64531797,  0.20157497, -0.52744202,
#        -0.55322926,  0.19628749,  0.19814919,  0.62991732, -0.55322788,
#        -0.50811187, -0.08054544,  0.19182307,  0.20157497, -0.48104278,
#         0.19886788, -0.37277348,  0.60108336, -0.24766297, -0.44042428,
#        -0.5419498 , -0.08351576, -0.58544385, -0.50811509,  0.19886788,
#        -0.56225338, -0.37277292,  0.19812645, -0.48103964,  0.72309532,
#        -0.2374513 , -0.37279075, -0.44045272,  0.43447291, -0.50810844,
#         0.6491482 ,  0.22044763, -0.50811808,  0.6010834 , -0.50811596,
#        -0.48104476,  0.62992267, -0.36997618,  0.25383308,  0.60108597,
#         0.62992164,  0.68119025, -0.37278522, -0.4404479 ,  0.20890651,
#        -0.37279098,  0.18200679,  0.45688721,  0.64914027, -0.55323026,
#         0.20030181, -0.50810766, -0.44045658,  0.649148  , -0.52744933,
#         0.19799015, -0.4068066 , -0.5274466 ,  0.59043057, -0.37278685,
#         0.19886788,  0.19903037, -0.56963339,  0.6010834 ,  0.60107864,
#        -0.56963463,  0.45689149, -0.50811256,  0.18238744, -0.50812076,
#         0.20042807,  0.67318201, -0.44045275, -0.50811146,  0.45688878,
#        -0.52744031, -0.54194705,  0.0818017 ,  0.19724908,  0.18322046,
#        -0.52744903, -0.37279211,  0.19886788,  0.46371478, -0.50811115,
#        -0.57578067,  0.66287724, -0.44045616,  0.5530176 , -0.4810517 ,
#        -0.50811808,  0.64914656,  0.19886788,  0.17906575,  0.55302067,
#        -0.52744815,  0.1816776 , -0.54194858, -0.37279549, -0.44044896])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
plt.scatter(pca0,pca1,c=y);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-8d9ca8e2024a> in <module>()
# ----> 1 plt.scatter(pca0,pca1,c=y);
#
# NameError: name 'y' is not defined

# %% [markdown]
# ### LDA - Misc Gensim Implementation

# %%
frequency = defaultdict(int)
for text in processed_list:
    for token in text:
        frequency[token] += 1

# %%
# https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value

sorted_frequency = sorted(frequency.items(), key=operator.itemgetter(1))
sorted_frequency[-20:]

# %%
for text in frequency:
    print(text)
# Out:
# ghostrid
# nyqu
# hav
# read
# book
# youv
# don
# undeny
# good
# job
# rev
# alway
# del
# lik
# amazon
# driv
# rt
# dwel
# past
# dream
# fut
# cont
# mind
# pres
# mom
# buddh
# swift
# fcf
# yield
# amzn
# stock
# prim
# blockchain
# bal
# chao
# trag
# rom
# anub
# goddess
# lprtg
# us
# star
# review
# dash
# camauk
# min
# ful
# hd
# car
# camer
# wid
# detail
# h
# list
# neuron
# radio
# tunein
# echo
# smart
# phonetv
# favorit
# med
# play
# find
# prol
# diff
# hous
# brand
# confus
# also
# sort
# main
# ap
# gratitud
# effect
# selfhelpbook
# spons
# selfm
# happy
# fre
# profound
# mov
# wom
# fight
# surv
# inspir
# pow
# tru
# story
# pleas
# mak
# dai
# affirm
# skil
# alex
# googl
# hom
# nee
# jvn
# lif
# avat
# last
# airbend
# complet
# sery
# bluray
# energy
# facebook
# appl
# netflix
# faang
# put
# tel
# ad
# commun
# repl
# would
# hap
# knew
# real
# felt
# wond
# lov
# asmsg
# rrbc
# ya
# fant
# get
# wish
# could
# hug
# every
# sav
# bernard
# jan
# auth
# world
# without
# col
# access
# rep
# brav
# year
# week
# malapeir
# upgrad
# ed
# robot
# synthes
# cloud
# comput
# webbasiert
# dynamisch
# itserv
# hit
# wal
# wrong
# baby
# civilw
# nurs
# struggles
# respect
# man
# ward
# surgeon
# mainerd
# quest
# forget
# ut
# thrilling
# thecraftsm
# pyschthril
# royal
# hook
# join
# cult
# expedit
# memento
# someth
# desp
# arcad
# fal
# hor
# mystery
# paranorm
# monst
# buy
# say
# fan
# gam
# thrones
# vik
# nnlights
# heav
# kindl
# se
# pandem
# tim
# travel
# kidnap
# new
# harry
# sciencefict
# kindleunlimit
# season
# saveluc
# pickupluc
# kittenseason
# begun
# first
# pregn
# mum
# ar
# night
# due
# next
# day
# help
# fed
# hungr
# beyond
# forest
# fairy
# tal
# fantasy
# kay
# l
# ling
# unlimit
# u
# celebr
# roy
# wed
# div
# engl
# castl
# dragon
# im
# sur
# siz
# bought
# cam
# pack
# two
# intrigu
# dar
# adv
# straight
# act
# excit
# wel
# writ
# reminisc
# capcom
# remov
# internet
# requir
# ban
# meg
# leg
# collect
# switch
# accord
# ebay
# auct
# stil
# pleaseclick
# ibook
# anyon
# tri
# arcg
# pro
# appstream
# andre
# tarkovsky
# stun
# rest
# fin
# film
# thesacr
# giv
# bounty
# releas
# sup
# nuk
# memoir
# retir
# nuclear
# submarin
# charl
# cranston
# jet
# readindy
# indieauth
# iartg
# eartg
# mgtab
# newgarret
# heart
# paranormalrom
# theyorkshireslash
# think
# work
# anoth
# twist
# com
# along
# bril
# edward
# ii
# want
# keep
# crown
# mortim
# depend
# los
# queen
# isabell
# sid
# w
# chant
# win
# vouch
# follow
# amp
# retweet
# tampc
# giveaway
# ch
# album
# best
# sel
# soundtrack
# guard
# galaxy
# awesom
# mix
# vol
# origin
# mot
# pict
# sou
# alibaba
# supermarket
# chin
# lightyear
# ahead
# show
# ta
# pittsburgh
# sit
# tour
# mon
# seem
# intend
# spring
# dont
# umbrell
# storm
# tissu
# know
# reelect
# wev
# jeanclaud
# junck
# pre
# euro
# cas
# black
# pearl
# thriller
# linanderson
# patrickdecourvoisy
# can
# fbi
# must
# stop
# kil
# rap
# tortureal
# nam
# g
# o
# s
# t
# r
# i
# d
# n
# y
# q
# a
# v

# %%
# get only words that appear more than 10 times
min10_texts = [[token for token in frequency if frequency[token] > 5] for text in frequency]

# %%
# create the dictionary and corpus (via gensim) of all the tweets
# dictionary = corpora.Dictionary(min10_texts)
# corpus = [dictionary.doc2bow(text) for text in min10_texts]

dictionary = corpora.Dictionary(processed_list)
corpus = [dictionary.doc2bow(text) for text in processed_list]

# %% [markdown]
# #### Run the model (LDA)

# %%
# fit LDA model
amzntweet_topics = LdaModel(corpus=corpus,
                           id2word=dictionary,
                           num_topics=20,
                           passes=10)

# %%
amzntweet_topics.get_topic_terms(3)
# Out:
# [(371, 0.038817),
#  (373, 0.038817),
#  (368, 0.038817),
#  (369, 0.038817),
#  (370, 0.038817),
#  (183, 0.038817),
#  (367, 0.038817),
#  (372, 0.038817),
#  (251, 0.0018484286),
#  (252, 0.0018484286)]

# %% [markdown]
# ### Train model on econ data...

# %%
# set the target
y = df_econ1.relevance

# %%
X_train, X_test, y_train, y_test = train_test_split(df_econ1['headline'], y, test_size=0.33, random_state=53)

# vectorize the text (ensure ONLY the text)
count_vectorizer = CountVectorizer(stop_words='english')
count_train = count_vectorizer.fit_transform(X_train)
# make sure to ONLY transform the test data
count_test = count_vectorizer.transform(X_test)
print(count_vectorizer.get_feature_names()[1000:1010])

# %%
# test classification on econ docs
nb_classifier = MultinomialNB()
nb_classifier.fit(count_train, y_train)
pred = nb_classifier.predict(count_test)
metrics.accuracy_score(y_test, pred)

# %%
metrics.confusion_matrix(y_test, pred, labels=[0,1])

# %% [markdown]
# ## Twitter Sentiment

# %%
# read in bigger data...
df_tweets = pd.read_pickle('tweet_data/tweet_master.pkl')
tweets = [x for x in df_tweets['text'] if str(x) != 'nan']
print(len(tweets))
# Out:
# 984609

# %%
def clean_links(tweet):
    no_link = re.sub(r'http\S+', '', tweet)
    no_mention = re.sub(r'@\S+', '', no_link)
    no_emoji = re.sub(r'[^\w\s,]', '', no_mention)
    return (no_emoji)

# %%
# 6 secs at 1mil tweets...
clean_list = []
for tweet in tweets:
    clean_list.append(clean_links(tweet))

clean_list[:10]
# Out:
# ['Jah Rastafari Crest Samsung Case  Samsung Galaxy S8 Saytoons Trenton Denver Brooklyn LosAngeles  via ',
#  'RT  This book is humorous, creepy, scary and suspenseful all in one\n\nWɪᴛᴄʜ Hᴜɴᴛᴇʀ Iɴᴛᴏ ᴛʜᴇ Oᴜᴛsɪᴅᴇ\n\nurbanfantasy Kind',
#  'RT  久々に本を一冊読み切りそうですこの本は著者が自らの経験から感じたことや思われたことを着色せず語られているので読みやすく分かりやすく今の時代と此れからの生き方を考える上では必読おススメです 守先生亀田女史甲野先生ご縁結びありがとうござい',
#  'ULATREE Women Criss Cross Front Tops Short Sl by ULATREE  via  ',
#  'RT  Do you like dialogues as powerful as dhai kilo ka haath Or get senti when some says Mere pass maa hai Tell us which B',
#  '  そーなんですねその方が安全かなぁ\n都心もヤバいですよ家の近所本屋さんないしAmazonか',
#  ' Amazonさんで19,000円しなかったと思う',
#  '日々の疲れは音楽で癒してｗΨAmazon\u3000ミュージックヒーリングベストセラー\u3000',
#  'USA 45 off, 44 Stars Solar  Motion Sensor Lights Outdoor 100 Led Super Bright W Details Its brightness gre ',
#  'RT  Y abrió los ojos, entornados, un halo de luz le llamaba, de una pantalla miles de amigos le saludaban, todos en su manob']

# %%
# NLTK Vader sentiment
sid = SentimentIntensityAnalyzer()

vader_list = []

for tweet in clean_list:
    ss = sid.polarity_scores(tweet)
    vader_list.append(ss)

# confirmed - returns dataframe with vader_sent correctly aligned with headlines (iffy when adding new column as list)
df_tweets['vader_sent'] = vader_list
df.info()

# %%
# TextBlob sentiment

textblob_list = []

for tweet in clean_tweets:
    x = TextBlob(tweet).sentiment.polarity
    textblob_list.append(x)

df_tweets['textblob_sent'] = textblob_list

# %% [markdown]
# # Economic Articles - Topic Modeling + Sentiment

# %% [markdown]
# ## Load econ data

# %%
df_econ = pd.read_csv('~/ds/data/nlp/Full-Economic-News-DFE-839861.csv', encoding='latin-1')
# df_econ2 = pd.read_csv('~/ds/data/nlp/us-economic-newspaper.csv', encoding='latin-1')
df = df[['relevance','headline']]
df.dropna(axis=0, how='all')
print(df.head())
print()
print(df.info())
# Out:
#   relevance                                           headline
# 0       yes              Yields on CDs Fell in the Latest Week
# 1        no  The Morning Brief: White House Seeks to Limit ...
# 2        no  Banking Bill Negotiators Set Compromise --- Pl...
# 3        no  Manager's Journal: Sniffing Out Drug Abusers I...
# 4       yes  Currency Trading: Dollar Remains in Tight Rang...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 2 columns):
# relevance    8000 non-null object
# headline     8000 non-null object
# dtypes: object(2)
# memory usage: 125.1+ KB
# None

# %% [markdown]
# ## Topic Modeling (x3)

# %%
# decent data summary.
# if used for classification, then short resample to get equally represented classes
df.groupby('relevance').count()
# Out:
#            headline
# relevance
# no             6571
# not sure          9
# yes            1420

# %% [markdown]
# ### 1. Model complete list (yes/no)

# %%
# df.headline[:20]

# %%
# count stopwords in each title...
# from nltk.corpus import stopwords
# stop = stopwords.words('english')

# train['stopwords'] = train['tweet'].apply(lambda x: len([x for x in x.split() if x in stop]))
# train[['tweet','stopwords']].head()

# %%
# only basic term frequency can be considered with LDA because it defines 
# its own PROBABALISTIC determination of topics / grouping / etc.

n_components = 6

tf_vectorizer = CountVectorizer(max_df=0.90, min_df=5,
                                ngram_range=(1,1),
                                max_features=1000,
                                stop_words='english')

# %%
tf = tf_vectorizer.fit_transform(df.headline)

# define model (lda) and model parameters, fit model to vectorized data
lda = LatentDirichletAllocation(n_components=n_components, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx), " ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
#         print (" ".join([feature_names[i]
#                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, vocab, n_components)
# Out:
# Topic 0: inflation report new bank spending home
# Topic 1: fed rates says economic year news
# Topic 2: tax plan money profit cut bush
# Topic 3: rate business post jobless washington finance
# Topic 4: stocks dow market prices dollar rally
# Topic 5: stock market deficit trade economy billion

# %% [markdown]
# ### 2. Model YES list

# %%
df_yes = df[df['relevance'] == 'yes']

# %%
df_yes.count()
# Out:
# relevance    1420
# headline     1420
# dtype: int64

# %%
# Set up vectorized / tokenized doc vectors and run topic modeling
n_components = 6

tf_vectorizer = CountVectorizer(max_df=0.90, min_df=5,
                                ngram_range=(1,1),
                                max_features=1000,
                                stop_words='english')

tf = tf_vectorizer.fit_transform(df_yes.headline)

# define model (lda) and model parameters, fit model to vectorized data
lda = LatentDirichletAllocation(n_components=n_components, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
# Define what is represented
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx), " ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
#         print (" ".join([feature_names[i]
#                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, vocab, n_components)
# Out:
# Topic 0: gain quarter output inflation wary increases
# Topic 1: economy fed rate rates inflation growth
# Topic 2: year ahead jobless tape wall street
# Topic 3: new stock recession news housing recovery
# Topic 4: business decline dollar finance trade report
# Topic 5: stocks market dow rally stock high

# %% [markdown]
# ### 2. Model NO list

# %%
df_no = df[df['relevance'] == 'no']

# %%
# Set up vectorized / tokenized doc vectors and run topic modeling
n_components = 6

tf_vectorizer = CountVectorizer(max_df=0.90, min_df=5,
                                ngram_range=(1,1),
                                max_features=1000,
                                stop_words='english')

tf = tf_vectorizer.fit_transform(df_no.headline)

# define model (lda) and model parameters, fit model to vectorized data
lda = LatentDirichletAllocation(n_components=n_components, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
# Define what is represented
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx), " ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
#         print (" ".join([feature_names[i]
#                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 4
display_topics(lda, vocab, n_components)
# Out:
# Topic 0: rates prices stocks dollar inflation rate
# Topic 1: market stock economy growth stocks profit
# Topic 2: fed says big bank money jobless
# Topic 3: dow world gains spending stocks rises
# Topic 4: new tax plan budget jobs economic
# Topic 5: deficit business trade recession news finance

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### TextBlob

# %% [markdown]
# https://planspace.org/20150607-textblob_sentiment/

# %%
# example
from textblob import TextBlob

statement = 'Today I went to Barbeque Nation and the Food was awesome'
sentiment = TextBlob(statement)
print("Sentiment Score: ", sentiment.sentiment.polarity)  # Result = 1.0
 
statement2 = "Today I went to Barbeque Nation and the Food was very good"
sentiment2 = TextBlob(statement2)
print("Sentiment Score: ", sentiment2.sentiment.polarity) # Result = 0.9
# Out:
# Sentiment Score:  1.0
# Sentiment Score:  0.9099999999999999

# %%
# example
sentiment3 = TextBlob('The sauce is not too thick.')
sentiment3.sentiment.subjectivity
# Out:
# 0.475

# %%
for title in df.headline[:10]:
    x = TextBlob(title).sentiment.polarity
    print('Polarity: {}; Text: {}'.format(x, title))
# Out:
# Polarity: 0.5; Text: Yields on CDs Fell in the Latest Week
# Polarity: 0.0; Text: The Morning Brief: White House Seeks to Limit Child Insurance Program
# Polarity: 0.0; Text: Banking Bill Negotiators Set Compromise --- Plan to Widen Banks' Entry To Securities Business Is Dropped as Vote Nears
# Polarity: -0.16666666666666666; Text: Manager's Journal: Sniffing Out Drug Abusers Is No Quick Fix
# Polarity: -0.17857142857142858; Text: Currency Trading: Dollar Remains in Tight Ranges Amid Wait for U.S. Jobs Data
# Polarity: 0.0; Text: Stocks Fall Again; BofA, Alcoa Slide
# Polarity: 0.3; Text: Bank of Montreal, Royal Bank Profits Rose in 2nd Period
# Polarity: 0.0; Text: Battle Over Medical Costs Isn't Over
# Polarity: 0.0; Text: Sequenom to Buy Gemini Genomics In Stock Accord
# Polarity: 0.5; Text: U.S. Dollar Falls Against Most Currencies; Decline Is Softened as Bond Rally Stalls

# %%
textblob_list = []
for title in df.headline:
    x = TextBlob(title).sentiment.polarity
    textblob_list.append(x)

df['textblob_sent'] = textblob_list
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 4 columns):
# relevance        8000 non-null object
# headline         8000 non-null object
# vader_sent       8000 non-null object
# textblob_sent    8000 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 250.1+ KB

# %% [markdown]
# http://www.nltk.org/howto/sentiment.html

# %% [markdown]
# ### NLTK Vader

# %% [markdown]
# **Vader Notes**
# Vader works well for social media as it captures not just polarity (positive or negativity) but also magnitude of that polarity, aka valence (hence the name: Valence... ). Examples? Sure:
# - Vader capture uppercase text so that 'WAY COOL' is interprettyed as more highly positive than 'way cool'.
# - Vader captures punctuation, so that 'nice!' is better than 'nice.'
# - Text pictures... are captured and recording as adding positivity or negativity to the statement.
#
# Thus in cases where there is a more extensive use of informal language to convey sentiment, Vader is an important tool. However, in more professional contexts such as finance, academia or otherwise, Vader loses a bit of its power.

# %%
import nltk
# nltk.download('vader_lexicon')
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize
# Out:
# /Users/jas/anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
sid = SentimentIntensityAnalyzer()

# %%
# this prints all headlines, for reference. Looks pretty good.

for title in df.headline:
    print(title)
    ss = sid.polarity_scores(title)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()
# Out:
# Yields on CDs Fell in the Latest Week
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Morning Brief: White House Seeks to Limit Child Insurance Program
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Banking Bill Negotiators Set Compromise --- Plan to Widen Banks' Entry To Securities Business Is Dropped as Vote Nears
# compound: 0.296, neg: 0.0, neu: 0.891, pos: 0.109,
# Manager's Journal: Sniffing Out Drug Abusers Is No Quick Fix
# compound: -0.7003, neg: 0.42, neu: 0.58, pos: 0.0,
# Currency Trading: Dollar Remains in Tight Ranges Amid Wait for U.S. Jobs Data
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stocks Fall Again; BofA, Alcoa Slide
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bank of Montreal, Royal Bank Profits Rose in 2nd Period
# compound: 0.4404, neg: 0.0, neu: 0.756, pos: 0.244,
# Battle Over Medical Costs Isn't Over
# compound: -0.3818, neg: 0.342, neu: 0.658, pos: 0.0,
# Sequenom to Buy Gemini Genomics In Stock Accord
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. Dollar Falls Against Most Currencies; Decline Is Softened as Bond Rally Stalls
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dow Falls 45.95, Late GM Surge Stanches Losses
# compound: -0.4019, neg: 0.278, neu: 0.722, pos: 0.0,
# MCI Surpasses Expectations On Earnings
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Defending Yourself Against Deflation
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Lending to Firms Projected to Grow 9.2% Next Year
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S., week ahead of economic summit, signals it wants lower interest rates
# compound: 0.2023, neg: 0.145, neu: 0.658, pos: 0.197,
# Net Worth, Not Income, Is Right Measure of Inequality
# compound: 0.2263, neg: 0.0, neu: 0.808, pos: 0.192,
# The Americas: Ecuador Struggles Toward a Dollar Economy
# compound: -0.3612, neg: 0.294, neu: 0.706, pos: 0.0,
# Dollar Declines as Players Take Profits From Rally and After Fed Boosts Rates
# compound: 0.6369, neg: 0.0, neu: 0.679, pos: 0.321,
# In Europe, Job Protections for Older Generation Are Barriers for Younger Workers; Earnings Gap Looms for Younger Generation Dependent on Short-Term Contracts
# compound: -0.1531, neg: 0.071, neu: 0.929, pos: 0.0,
# Outlook for Business Investment Improves, but Softness May Persist
# compound: 0.2263, neg: 0.0, neu: 0.808, pos: 0.192,
# Tech Sector in Hiring Drive; Google, Intel Add Workers as Profits Snap Back; Start-Ups Also Fight for Talent
# compound: 0.4767, neg: 0.112, neu: 0.644, pos: 0.245,
# Fed's Greenspan Refuses to Accept Blame for Recession; Upturn's Pace Is 'Glacial'
# compound: -0.3818, neg: 0.31, neu: 0.536, pos: 0.155,
# They're Writing the Checks; Ray Lane and Matthew Rogers on the new energy math for venture capitalists
# compound: 0.2732, neg: 0.0, neu: 0.884, pos: 0.116,
# Deal Journal / Breaking Insight From WSJ.com
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Chevron Falls 2.4%; Jabil Jumps
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. News: Cost-Cutting Detroit Will Close 77 Parks
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bond Prices Tumble as Dollar's Plunge Prompts Additional Fears on Inflation
# compound: -0.4215, neg: 0.219, neu: 0.781, pos: 0.0,
# Producer Prices Decreased 0.2% In November --- Drop Caused by 1.5% Fall For Energy and Decline Of 0.5% in Food Costs
# compound: 0.0, neg: 0.091, neu: 0.819, pos: 0.091,
# Metals Analyst Backs Gold After 2 Years Of Bearish Forecasts
# compound: -0.0516, neg: 0.13, neu: 0.87, pos: 0.0,
# Is Warburg Pincus's Magic Waning? --- Investor Pins Hope On Turnarounds
# compound: 0.4404, neg: 0.0, neu: 0.775, pos: 0.225,
# Consumer Credit Continued Surge In July, Fed Says --- But Increase of $7.11 Billion Was Smaller Than Rises In Previous Two Months
# compound: 0.5994, neg: 0.0, neu: 0.803, pos: 0.197,
# Consumer Spending Rises a Bit; Incomes Climb Solidly, but Stronger Economic Growth Faces Headwinds
# compound: 0.7783, neg: 0.0, neu: 0.618, pos: 0.382,
# Small-Scale Deficit Deal Increases Risk of U.S. Downgrade
# compound: -0.5859, neg: 0.444, neu: 0.556, pos: 0.0,
# Crist Completes His Reinvention
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Global View: Breaking Up Is Hard, But Let's Not Freak Out
# compound: 0.2514, neg: 0.109, neu: 0.703, pos: 0.188,
# Tuesday's markets: Prices of bonds, stocks drop; Dollar weakens
# compound: -0.5267, neg: 0.386, neu: 0.614, pos: 0.0,
# U.S. News: U.S. Watch
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Family Money: How I Got Burned by Beanie Babies
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Unemployment Claims Hit Eight-Year Low; They're at Levels Last Seen During Economic Expansions
# compound: -0.6124, neg: 0.312, neu: 0.688, pos: 0.0,
# New Job Data Cast Doubt on Economy's Slowing
# compound: -0.3612, neg: 0.263, neu: 0.737, pos: 0.0,
# High Court Rules Limits May Be Set On Contributions in State Campaigns
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dollar Jumps, Aided by Data
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# ... But Is '70s-Style Inflation the Real Enemy?
# compound: -0.5423, neg: 0.333, neu: 0.667, pos: 0.0,
# Two Borrowers Offer Eurobonds, but Issues Find Little Support --- Special to The Wall Street Journal
# compound: 0.7403, neg: 0.0, neu: 0.691, pos: 0.309,
# ACS Agrees to Buy Lockheed's IMS Unit
# compound: 0.2023, neg: 0.0, neu: 0.769, pos: 0.231,
# In India, a Tough Row to Hoe for T. Rowe
# compound: -0.128, neg: 0.158, neu: 0.842, pos: 0.0,
# Despite Rally, Worries Over Inflation Remain --- Economists Search For Better Indicators Than the Jobs Report
# compound: 0.6407, neg: 0.0, neu: 0.728, pos: 0.272,
# Retailers Stock Up on Caution
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Some Stocks Had Big Fourth-Quarter Gains Despite a Plunge in Broad Market Averages
# compound: 0.34, neg: 0.0, neu: 0.821, pos: 0.179,
# Fed Approves Loan Facility Tied To Y2K Problems
# compound: 0.0, neg: 0.237, neu: 0.526, pos: 0.237,
# Chip-Equipment Industry Is Still Hurting
# compound: -0.4019, neg: 0.403, neu: 0.597, pos: 0.0,
# Massive Intervention Slows Dollar's Surge
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bond Prices Are Little Changed In Slow Trading As Investors Brace for January Employment Data
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Adobe to Acquire Frame For $500 Million in Stock --- Publishing-Software Firm Posts 96% Rise in Profit For the Second Quarter
# compound: 0.4404, neg: 0.0, neu: 0.873, pos: 0.127,
# U.S. News: Producer Prices Log Another Monthly Drop, Showing the Weakness in Global Demand
# compound: -0.6597, neg: 0.368, neu: 0.632, pos: 0.0,
# Eurodollar Bonds Rise 1/8 to 1/4 Point On the Firmer Dollar --- Special to The Wall Street Journal
# compound: 0.4019, neg: 0.0, neu: 0.863, pos: 0.137,
# Indian Rupee Falls Again
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Corporations' Orders to Buy Push Up Dollar --- An Early Slump Followed Yeutter Trade Remark; No Fed Action Is Seen
# compound: -0.296, neg: 0.104, neu: 0.896, pos: 0.0,
# MarketWatch Weekend Investor: Buyer Beware: In Acquisitions, Sellers Frequently Know Best
# compound: 0.6369, neg: 0.0, neu: 0.704, pos: 0.296,
# IMS Struggles to Regain Trust After Failed Deal
# compound: -0.3612, neg: 0.411, neu: 0.355, pos: 0.234,
# Futures Markets: Treasury Bond Contracts End Near Five-Year Highs
# compound: 0.2023, neg: 0.0, neu: 0.816, pos: 0.184,
# Bummer of a Recovery; On economic growth, real GDP has risen 0.8% over the 13 quarters since the recession began, compared to an average increase of 9.9% in past recoveries.
# compound: -0.128, neg: 0.153, neu: 0.708, pos: 0.139,
# AMR, Southwest Profits Surge Even as Fuel Prices Stay High
# compound: 0.4404, neg: 0.0, neu: 0.756, pos: 0.244,
# How To Play Rising Rates; The Bond Boom Has Left Many Investors Vulnerable to a Surprise Jump in Interest Rates. Here's How to Protect Yourself--and Profit
# compound: 0.8779, neg: 0.056, neu: 0.56, pos: 0.383,
# Romney Takes Aim at Obama Again; Republican Candidate Steers Away From Recent Squabbles With Rivals on the Campaign Trail
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# June 13 - 17; This Week: GOP Debate, Greek Respite, RIM Trouble
# compound: -0.4019, neg: 0.213, neu: 0.787, pos: 0.0,
# MCI to Emerge From Bankruptcy; Telecom Firm Is to Issue New Securities and Pay $750 Million for Investors
# compound: 0.2023, neg: 0.071, neu: 0.816, pos: 0.112,
# Planning 'Oracle' Robert Yaro to Retire from Regional Group; Longtime Head of Planning Organization Was Ready to Back Unpopular Causes
# compound: 0.3612, neg: 0.0, neu: 0.884, pos: 0.116,
# Gaining Capital
# compound: 0.4215, neg: 0.0, neu: 0.263, pos: 0.737,
# Tracking the Economy: Economists Follow February Job Data Upward and Boost Output Estimates
# compound: 0.4019, neg: 0.0, neu: 0.816, pos: 0.184,
# Silver Flirts With $50
# compound: 0.1779, neg: 0.0, neu: 0.638, pos: 0.362,
# New home sales rose 7.1% in May; Personal income and spending up 0.3%
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Long-Term Unemployment Ripples Through One Town
# compound: -0.4404, neg: 0.367, neu: 0.633, pos: 0.0,
# Hanoi Web Crackdown Hits Blogs; Foreign Firms Fret
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. Merchandise Trade Gap Shrank During 1st Quarter
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Burning Coal Emits Dangerous Pollutants
# compound: -0.4767, neg: 0.437, neu: 0.563, pos: 0.0,
# U.S. News: Summers Outlines Risks to Recovery
# compound: -0.2732, neg: 0.259, neu: 0.741, pos: 0.0,
# America's New Deal for Global Energy Mix
# compound: 0.2732, neg: 0.0, neu: 0.741, pos: 0.259,
# Bernanke Faces Skepticism Over Policy
# compound: -0.25, neg: 0.333, neu: 0.667, pos: 0.0,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Use of stock-options contracts climbs as investors seek hedge
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Fed's Loans: Foreign Firms Received Funds --- Data From Fed Show Lenders Got Emergency Cash
# compound: -0.3818, neg: 0.148, neu: 0.852, pos: 0.0,
# Asian Shares Mixed
# compound: 0.296, neg: 0.0, neu: 0.476, pos: 0.524,
# Record Exports Cut Trade Gap For 1st Quarter --- Machine Sales Helped Slice Deficit to $35.95 Billion; Imports Also Set Mark
# compound: -0.5859, neg: 0.202, neu: 0.798, pos: 0.0,
# REVIEW & OUTLOOK (Editorial): The Banzai Pipeline
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Going Global: Europe's Stock Run May End Soon; With Higher Interest Rates Looming, Some Analysts Favor U.S. Equities Market
# compound: 0.6369, neg: 0.065, neu: 0.69, pos: 0.246,
# The Afternoon Report: Reckoning Rates
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Treasurys Prices Continue to Climb on Weakness In the Stock Market, Signs of a Slowing Economy
# compound: -0.4215, neg: 0.167, neu: 0.833, pos: 0.0,
# The Federal Reserve: From Central Bank to Central Planner
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Taylor Admits To a Weakness In Policing BCCI
# compound: -0.1531, neg: 0.28, neu: 0.5, pos: 0.22,
# Inflation Estimates Creep Up; Getting a Fix on Prices and Oil Grows Increasingly Crucial
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stocks Maintain Recent Gains, Giving Investors Renewed Hope
# compound: 0.7717, neg: 0.0, neu: 0.394, pos: 0.606,
# U.S. Dollar Scores Narrow Gains Against Mark, Yen, Pound ---- Special to The Wall Street Journal
# compound: 0.6249, neg: 0.0, neu: 0.733, pos: 0.267,
# The Afternoon Report: The Economics of Truth
# compound: 0.3182, neg: 0.0, neu: 0.723, pos: 0.277,
# What's Ahead -- People & Events to Watch in the Coming Week
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Gates Says Foreign Aid Needed for Global Stability
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Ford Uses Aggressive Marketing Approach in Thailand --- Focus on Financing Strategies Is Key Reason for Increased Market Share
# compound: 0.4019, neg: 0.073, neu: 0.731, pos: 0.196,
# Bigger Bills: With Costs Rising, Companies Move To Increase Prices; Mix of Inflation, Slowdown Poses Challenge for Fed; Energy Takes Broad Toll; Dow Surges on GDP Figures
# compound: 0.5719, neg: 0.0, neu: 0.808, pos: 0.192,
# Home Depot Climbs, Coca-Cola Slides
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Record Settlement on Table, But J.P. Morgan Faces Fight
# compound: -0.3818, neg: 0.245, neu: 0.755, pos: 0.0,
# The Keynesian Growth Discount; The results of our three-year economic experiment are in.
# compound: 0.3818, neg: 0.0, neu: 0.822, pos: 0.178,
# Investors Find the 'Other' Billion-Person Nation; It's India, and Portfolio Managers Say It Might Outshine China; Foreign Investing Is Opening Up
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Cisco and Charles River Soar; Hospira, Toll Brothers Stumble; Other Housing Firms Drop As Do Federated, Disney Amid Broad Economic Fears
# compound: -0.5994, neg: 0.205, neu: 0.795, pos: 0.0,
# Argentina Says Progress Made In IMF Talks --- Unclear Whether Banks Will Be Persuaded to Roll Over Loan Due on Wednesday
# compound: 0.2023, neg: 0.084, neu: 0.798, pos: 0.118,
# Economy Gives Social Security a Reprieve --- Latest Forecast Extends Trust Fund's Solvency By Three Years, to 2032
# compound: 0.7351, neg: 0.0, neu: 0.66, pos: 0.34,
# How to Think Smarter About Risk; Too many investors may be taking big chances with their money because they aren't considering the most important asset of all: themselves
# compound: 0.763, neg: 0.06, neu: 0.661, pos: 0.278,
# A Tale of Two States
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Jobless Rate May Signal Slowing Growth --- January Rise to 5.7% Comes After Year-Long Drop; Fed Moves Seen as Key
# compound: 0.128, neg: 0.093, neu: 0.793, pos: 0.115,
# Fed's Credit Easing and Dollar's Fall Are Expected to Yield Mixed Results
# compound: 0.5574, neg: 0.0, neu: 0.685, pos: 0.315,
# Consumer Prices Didn't Increase At All in January --- Situation Hasn't Occurred In Over Four Years; Inflation Is Seen Tamed
# compound: -0.2411, neg: 0.094, neu: 0.906, pos: 0.0,
# Gambling on Procter's Return
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Oracle Jumps 11% on Strong Growth; Circuit City Shares Ease, CarMax Hits All-Time High, Morgan Stanley Moves Up
# compound: 0.8625, neg: 0.0, neu: 0.569, pos: 0.431,
# An Unnecessary Fix for the Fed; Legislation in pursuit of 'transparency and accountability' has little to do with either.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Asean Chief Paints Region as Safe Haven
# compound: 0.4404, neg: 0.0, neu: 0.674, pos: 0.326,
# FreeShop.com, Scoot.com, Osicom, Gentex Rise, As Tech Stocks Help Push Nasdaq to New Record
# compound: 0.4019, neg: 0.0, neu: 0.828, pos: 0.172,
# House Agrees to Cut Capital Gains Tax, Soundly Defeating Democratic Proposal --- Vote, Key Victory for Bush, Increases the Likelihood Of Tax-Cut Law in 1989
# compound: -0.128, neg: 0.157, neu: 0.702, pos: 0.14,
# It's Time to Take Some Profits
# compound: 0.4404, neg: 0.0, neu: 0.633, pos: 0.367,
# Currency Traders Return to Strategy Of Unloading Yen, Buying European
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bookshelf: Toward a 'Warrior Age'
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Adelphia Overstated Cash Flow, Revenue Over Past Two Years
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Economy; THE OUTLOOK: Could Overseas Financing Hurt the U.S.?
# compound: -0.5267, neg: 0.274, neu: 0.726, pos: 0.0,
# MarketWatch: Teens Can Still Find Summer Jobs
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Outlook -- After the Rise: The Market's Message
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. News: Hints of Stability Emerge in Fragile Financial System
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Singapore's Reputation as Haven for Solid Gains Takes a Hit, but Managers Urge Long-Term View
# compound: 0.25, neg: 0.0, neu: 0.8, pos: 0.2,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Labor Department Concedes Disparity in Estimates of Jobs by U.S. and States
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Mortgage Rates Reverse Course and Fall
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Volatility Is Lowered to Attract Options Buyers
# compound: 0.25, neg: 0.167, neu: 0.556, pos: 0.278,
# The Willy-Nilly Dollar
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Deals & Deal Makers: Archipelago to Set Up New Stock Market
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Atlas Air to Unveil Agreement to Fly Planes for FedEx
# compound: 0.4939, neg: 0.0, neu: 0.738, pos: 0.262,
# Post Office and Wall Street to Stay Open Dec. 26, Despite U.S. Workers' Day Off
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Fixed Rates Rose In the Latest Week
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Legislative Action On Market Reform Isn't Expected Soon
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Year-End Review of Markets and Finance: What Was News
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# EuroLinks Daily View: Blackstone Stake Is Just The Beginning for Beijing's Billions
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stocks Gain; Bond Slump Continues --- Dow Jones Industrials Advance 30.19 Points; Dollar Rises Modestly
# compound: 0.5267, neg: 0.0, neu: 0.805, pos: 0.195,
# U.S. News: Doctors' Payments Snag Health Bill
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# JDS Uniphase, Brocade Tumble As Rate Cut Reinforces Pessimism
# compound: -0.5574, neg: 0.397, neu: 0.603, pos: 0.0,
# Canadian Business Confidence Grew in First Quarter
# compound: 0.5106, neg: 0.0, neu: 0.645, pos: 0.355,
# Pricing Power: Lost But Not Forgotten?
# compound: -0.1615, neg: 0.289, neu: 0.502, pos: 0.209,
# Global Finance: Deal Maker Pulls Off a Pair --- REIT Chief Agrees to Sell ARC Healthcare Trust to Ventas, Acquire Hotel Chain
# compound: 0.6249, neg: 0.0, neu: 0.788, pos: 0.212,
# Bill Extending Emergency Jobless Aid Is Passed by Senate Finance Committee
# compound: -0.3818, neg: 0.206, neu: 0.794, pos: 0.0,
# Resilience Is the Key As Stocks Gain Anew
# compound: 0.5267, neg: 0.0, neu: 0.673, pos: 0.327,
# Options Report: Traders Buy Bank One Call Options on Hope Retirement of CEO Will Spark Turnaround
# compound: 0.5859, neg: 0.0, neu: 0.745, pos: 0.255,
# Alcoa, Coca-Cola, 3M Lead the Dow
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Letters to the Editor: Another Friend of Business
# compound: 0.4939, neg: 0.0, neu: 0.686, pos: 0.314,
# Housing Starts Increased 2.4% During July --- Multifamily Units Pace Rise, But Sector Is Expected To Soften as Rates Climb
# compound: 0.2732, neg: 0.0, neu: 0.9, pos: 0.1,
# Let's Not Panic and Ruin the World
# compound: 0.6979, neg: 0.0, neu: 0.464, pos: 0.536,
# Politics & Economics: Center-Left Appears to Unseat Italy's Berlusconi; If Thin Victory Stands, Winner Prodi Would Face Tough Opposition Coalition
# compound: 0.5106, neg: 0.067, neu: 0.762, pos: 0.17,
# Raise Interest Rates, Make Grandma Smile
# compound: 0.6705, neg: 0.0, neu: 0.421, pos: 0.579,
# Big Fine in Metals Case; Hedge-Fund Trader to Pay $1 Million in Market-Manipulation Settlement
# compound: 0.1027, neg: 0.092, neu: 0.789, pos: 0.118,
# Bush Officials Draft Broad Plan For Free-Market Economy in Iraq
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dollar Exceeds Most Major Currencies As Traders Put Upper Limits to the Test
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. News --- THE OUTLOOK: Tide Reverses in Latin America
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Economists Grow Less Pessimistic on '87 --- Data Indicate Stronger-than-Expected Start
# compound: -0.2975, neg: 0.181, neu: 0.819, pos: 0.0,
# Differences Among Money-Market Funds Produce Varying Yields and Levels of Risk
# compound: -0.2732, neg: 0.174, neu: 0.826, pos: 0.0,
# Taiwan Opens Market To Direct Investment By Foreign Insurers
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Fed's Mortgage Plan Lowers Its Sights
# compound: -0.128, neg: 0.231, neu: 0.769, pos: 0.0,
# Key Interest Rates
# compound: 0.4588, neg: 0.0, neu: 0.4, pos: 0.6,
# Dollar Finishes Narrowly Mixed; Gold Declines $1
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Facebook Awaits Index 'Like'
# compound: 0.0772, neg: 0.0, neu: 0.698, pos: 0.302,
# Stocks Wilt as a Difficult Week Ends
# compound: -0.3612, neg: 0.333, neu: 0.667, pos: 0.0,
# Saving Is Something You Should Do Every Day
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Pending Home Sales Slip in June; Housing Recovery Remains Choppy Despite Retreat in Interest Rates
# compound: -0.4717, neg: 0.239, neu: 0.761, pos: 0.0,
# Bulls Seek Fresh Highs Ahead of New Year
# compound: 0.3182, neg: 0.0, neu: 0.753, pos: 0.247,
# Study Sees Boston Rail Link As an Engine for Growth
# compound: 0.3818, neg: 0.0, neu: 0.776, pos: 0.224,
# ENTERPRISE
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Ultrashort Bond Funds: Are They Ultrasafe?; These funds are favorites again, five years after big losses.
# compound: 0.0258, neg: 0.138, neu: 0.718, pos: 0.144,
# Wednesday's markets: Stocks mixed, bonds decline; Dollar improves
# compound: 0.4215, neg: 0.0, neu: 0.714, pos: 0.286,
# Starting Out: When One Door Closes...
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Fed May Have Boosted Rates In Part to Satisfy Expectations
# compound: 0.6705, neg: 0.0, neu: 0.593, pos: 0.407,
# Some economists warn that inflation may be back to haunt the economy
# compound: -0.4767, neg: 0.291, neu: 0.709, pos: 0.0,
# Banks' Foreign-Exchange Revenues Dive After Wrong Guessing on Dollar's Strength
# compound: 0.0258, neg: 0.217, neu: 0.559, pos: 0.224,
# As Costs Soar, Taxpayers Target Pensions of Cops and Firefighters
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# REVIEW & OUTLOOK (Editorial) Cutting the Budget -- X: Cut to What Purpose?
# compound: -0.3818, neg: 0.265, neu: 0.735, pos: 0.0,
# Large Stock Focus: GE Declines 3.8%; Conoco Gains 2.9%
# compound: 0.34, neg: 0.0, neu: 0.769, pos: 0.231,
# Crimson Blues: Harvard Clash Pits Entrenched Faculty Vs. Brusque Leader; Summers's Executive Style Hits Academic Roadblock; Board Digs In for Fight; A Firestorm Over Gender
# compound: -0.3818, neg: 0.102, neu: 0.898, pos: 0.0,
# Investors Race to Purchase Latin Bonds --- Signs of Regional Rebound, Mexican Bond Payment Lift Lenders' Confidence
# compound: 0.5106, neg: 0.0, neu: 0.829, pos: 0.171,
# Senate Approves Bill to Restore Money For Food-Safety Initiative, Farm Aid
# compound: 0.5994, neg: 0.0, neu: 0.647, pos: 0.353,
# Myerson Trial Scrutinizes Subject Close to Most Law Firms: Billing
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# REVIEW & OUTLOOK (Editorial): Tower of Babble
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dow Erases Gains for the Year; Tumultuous Week Shatters Market Calm as Global Growth Fears Rattle Investors
# compound: 0.5423, neg: 0.121, neu: 0.563, pos: 0.316,
# Economy to Get Stronger in '88, Purchasers Say --- Survey, Taken After Crash, Cites Export Business; Mild Inflation Rise Seen
# compound: -0.0258, neg: 0.116, neu: 0.773, pos: 0.112,
# For John Crow, Zero Inflation Is No. 1 Goal
# compound: -0.296, neg: 0.239, neu: 0.761, pos: 0.0,
# Trade Deficit Shrinks, Sending Positive Signal --- Merchandise Gap Narrowed In November as Imports Fell More Than Exports
# compound: 0.2263, neg: 0.121, neu: 0.717, pos: 0.161,
# Yahoo's Quarter Net Tops Expectations
# compound: 0.5106, neg: 0.0, neu: 0.548, pos: 0.452,
# Many Businesses Are Taking Longer To Pay Their Bills
# compound: -0.1027, neg: 0.149, neu: 0.851, pos: 0.0,
# Art Market Euphoria Is Wearing Off; Realism's Setting In After Stock Drop
# compound: 0.4939, neg: 0.128, neu: 0.61, pos: 0.262,
# Junk-Bond Boom Takes a Timeout
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Communication Breakdown: Tense Negotiations Inside the Fed Produced Muddled Signals to Markets
# compound: -0.34, neg: 0.179, neu: 0.821, pos: 0.0,
# Bond Investors World-Wide Have Had Little to Cheer About So Far This Year
# compound: 0.4627, neg: 0.0, neu: 0.799, pos: 0.201,
# A Growing Economy Can Pay Its Bills
# compound: 0.0772, neg: 0.197, neu: 0.563, pos: 0.239,
# Left Behind -- Casualties of a Changing Job Market --- Looking Longer: Why for Many This Recovery Feels More Like a Recession --- As Economy Expands Slowly, Payrolls Keep Shrinking; Downside of Productivity --- Terri Brooks's New Prospect
# compound: 0.081, neg: 0.12, neu: 0.73, pos: 0.151,
# Higher Bond Yields May Not Skewer Stocks; Some Traders See Long-Term Rates As Simply Returning to Normal In a Sign of a Strong Economy
# compound: 0.5106, neg: 0.0, neu: 0.864, pos: 0.136,
# Stocks Lurch to Small Gains; Blue Chips Seesawed as Investors Digested a Mix of Economic and Earnings News
# compound: 0.34, neg: 0.0, neu: 0.87, pos: 0.13,
# Budget deficit grew in the latest month to $40.26 billion
# compound: -0.4019, neg: 0.231, neu: 0.769, pos: 0.0,
# Getting Going: How to Navigate the Fixed-Income Shoals
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Economy: Productivity Gains Spark Optimism on Economy
# compound: 0.7783, neg: 0.0, neu: 0.391, pos: 0.609,
# Venture-Capital Funding for Small Companies Plunges
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Nasdaq: Hindsight Says to Delay IPO --- Regulators Probe Exchange, Banks
# compound: -0.3182, neg: 0.187, neu: 0.813, pos: 0.0,
# Letter From the Publisher: A Report to The Wall Street Journal's Readers
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. Inflation Virtually Flat
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# State Seeks to Repayment of Unemployment Fraud
# compound: -0.7717, neg: 0.573, neu: 0.427, pos: 0.0,
# Fed's Yellen Remains Mum on Timing of Rate Change; Chairwoman Unwilling to Signal Any Shift in Bank's Plans at Conference
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Money Rates
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# A Year of Living on the Brink
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Consumer Prices Slow Advance From January --- February's Increase of 0.5% Is More Modest, but Still Disturbs Some Analysts
# compound: -0.4939, neg: 0.171, neu: 0.756, pos: 0.073,
# Gold Rises Slightly on Bargain Interest
# compound: 0.5037, neg: 0.0, neu: 0.484, pos: 0.516,
# So, What Really Drives the Stock Market?; Politics Certainly Can Play Role, But From Teapot to CIA Leaks, Economy Has Had Lasting Impact
# compound: 0.5859, neg: 0.0, neu: 0.814, pos: 0.186,
# Pathmark Posts Profit, Not Including Items From Restructuring
# compound: 0.4404, neg: 0.0, neu: 0.707, pos: 0.293,
# Ford Motor Credit's Offering Of Debt Gets Warm Reception
# compound: -0.1531, neg: 0.219, neu: 0.614, pos: 0.167,
# Authorities Describe 'Lone Wolf'
# compound: -0.2732, neg: 0.412, neu: 0.588, pos: 0.0,
# MANSION --- Jumbo Jungle: Loans that Dwarf the Definition of Jumbo
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Worthen Notes Dim Assessment Of Its Condition
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Large Stock Focus: Microsoft, Cisco, H-P Intel Gain
# compound: 0.5267, neg: 0.0, neu: 0.673, pos: 0.327,
# Tightening the Credit Screws; Community banks are still offering loans. But businesses have to jump through a lot more hoops to get them.
# compound: 0.1531, neg: 0.081, neu: 0.813, pos: 0.106,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Oil's Slippery Dollar Link
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# City News: State Budget In for a Loss
# compound: -0.3182, neg: 0.277, neu: 0.723, pos: 0.0,
# Low-Cost Clinics: Best Way to Treat Substance Abuse
# compound: 0.4019, neg: 0.261, neu: 0.311, pos: 0.429,
# GAO: U.S. Foreclosure Review Could Have Generated Higher Payments; Review Could Have Delivered $1.5 Billion More to Consumers if Not Halted, Federal Watchdog Finds
# compound: -0.128, neg: 0.061, neu: 0.939, pos: 0.0,
# Bond Prices Fall on News of Big Jump In Money Supply for Week and Month
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# When It's the Time for Plan B
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Gateway, Hewlett-Packard Rise Amid Enthusiasm for Tech Stocks
# compound: 0.4404, neg: 0.0, neu: 0.707, pos: 0.293,
# Senate Committee Approves Extension Of Jobless Benefits
# compound: 0.6486, neg: 0.0, neu: 0.485, pos: 0.515,
# Philadelphia Fed Survey Increases Growth Forecast
# compound: 0.3818, neg: 0.0, neu: 0.658, pos: 0.342,
# Mexican Growth: Too Much of a Good Thing? --- Deteriorating Trade Balance Could Spur a Correction If Oil Prices Fall Sharply
# compound: 0.6705, neg: 0.0, neu: 0.756, pos: 0.244,
# India's Tech Sector Braces for Slowdown
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Must We Save for Our Grandchildren?
# compound: 0.4939, neg: 0.0, neu: 0.61, pos: 0.39,
# Washington Should Lock In Low Rates
# compound: -0.2732, neg: 0.296, neu: 0.704, pos: 0.0,
# Investors Now View the Stock Market With Less Greed and Much More Fear
# compound: -0.7096, neg: 0.349, neu: 0.651, pos: 0.0,
# Abreast of the market: The landing: Between a soft and hard place: In stocks, jitters over possibility of a recession
# compound: -0.4939, neg: 0.208, neu: 0.792, pos: 0.0,
# Hexaware Profit Drops 33%
# compound: 0.4404, neg: 0.0, neu: 0.508, pos: 0.492,
# Financials Stage a Comeback As Dow Banks 58.70 Points
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. Stock Gains Spur European, Asian Markets; London Sets Record as Russian Rally Continues
# compound: 0.34, neg: 0.0, neu: 0.844, pos: 0.156,
# Stocks Edge Higher, Ignoring Bad News On Economy, Oil
# compound: -0.7351, neg: 0.47, neu: 0.53, pos: 0.0,
# Tokyo Reduces Import Levies On 1,800 Items --- U.S. Expects Little Impact On Japan Trade Surplus; Further Steps Awaited
# compound: -0.0258, neg: 0.058, neu: 0.942, pos: 0.0,
# Mass Layoffs, Led by California, Rose 54% in 4th Period --- Golden State Tallied 154,000, But the Midwest Saw Huge Percentage Gains
# compound: 0.5719, neg: 0.0, neu: 0.81, pos: 0.19,
# Canada Isn't Natural-Gas Panacea for U.S. --- Doubts Are Growing About Region's Ability to Boost Exports
# compound: 0.5423, neg: 0.105, neu: 0.574, pos: 0.321,
# Chrysler Dealers Defend 'Halftime in America' Ad
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Our Uncertain Economy
# compound: -0.296, neg: 0.524, neu: 0.476, pos: 0.0,
# White House official gets lesson on Fed's sensitivity
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Crude Settles Below $95
# compound: -0.5719, neg: 0.552, neu: 0.448, pos: 0.0,
# Bernanke's Seoul Brothers; Loose money in America, capital controls abroad.
# compound: -0.3182, neg: 0.204, neu: 0.796, pos: 0.0,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Gasoline Price Rise Worries Auto Makers --- Fewer Purchases of Costly Sport-Utility Vehicles Is Feared
# compound: -0.7506, neg: 0.381, neu: 0.619, pos: 0.0,
# Though Bonds Began Weekend With Price Jump, Some Analysts Hold Cheers Until Next Fed Move
# compound: 0.4767, neg: 0.0, neu: 0.819, pos: 0.181,
# Renting Justice: Retired Judges Seize Rising Role in Settling Disputes in California --- Many Jurists Strive to Get Right Experience, Leave Early to Raise Earnings --- But Will the Courts Suffer?
# compound: -0.34, neg: 0.183, neu: 0.726, pos: 0.091,
# Small Banks in U.S. Face Their Own Year-End Cliff
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Too Much Money Is Beyond Legal Reach
# compound: 0.1531, neg: 0.0, neu: 0.658, pos: 0.342,
# After the Fall: Even with stocks in a swoon, you can still take steps to limit cracks in your nest egg
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# What Slowdown?
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Moving the Market -- MoneyBeat: Wall Street Speaks Up for Workers
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Home Sales Drop 6.6% on Rising Interest Rates
# compound: 0.2263, neg: 0.189, neu: 0.541, pos: 0.27,
# A Resolution to Catch the 'January Effect'
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Abreast of the market: Industrials fell 11.35 to 3518.85 as poor economic performance data end rally
# compound: -0.4767, neg: 0.171, neu: 0.829, pos: 0.0,
# Bank of Japan is lowering rates to boost economy
# compound: 0.1779, neg: 0.171, neu: 0.598, pos: 0.231,
# Speech of the Week; Another regulator comes out for regulatory simplicity.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Mortgage Rates Slide for a 7th Straight Week
# compound: 0.2263, neg: 0.0, neu: 0.759, pos: 0.241,
# Not So Special: `Specialist' IPO Fails to Impress
# compound: -0.3345, neg: 0.4, neu: 0.38, pos: 0.22,
# Bush Pins the Blame For '92 Election Loss On Alan Greenspan
# compound: -0.5719, neg: 0.343, neu: 0.657, pos: 0.0,
# Why Oil Prices May Head Lower, for Now
# compound: -0.296, neg: 0.239, neu: 0.761, pos: 0.0,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Draghi Opens Door to Bigger ECB Crisis Role
# compound: -0.6249, neg: 0.369, neu: 0.631, pos: 0.0,
# Jobless Aid Splits Parties, Experts; Budget Agreement Excludes Extension of Jobless Benefits, But Parties Keep Debating Program's Impact
# compound: 0.8807, neg: 0.0, neu: 0.556, pos: 0.444,
# IPO Outlook: Many of August's IPOs Rebound to Shine
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Worries Rebound on Bull's Birthday
# compound: -0.4215, neg: 0.412, neu: 0.588, pos: 0.0,
# Minister to Detail Steps to Revive Japanese Banks
# compound: 0.34, neg: 0.0, neu: 0.745, pos: 0.255,
# Consumers Grow More Upbeat, Nudging Up Sales at Retailers
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# New Kids of Venture Investing: Web-Struck Titans of Wall Street
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Fed Looks Likely to Stick to Policy Path; Officials On Track to Cut Bond Buys to $45 Billion, Maintain Rate Flexibility at Next Week's Meeting
# compound: 0.0772, neg: 0.076, neu: 0.836, pos: 0.087,
# Blackstone Reaches Deal To Revamp Hilton's Debt
# compound: -0.3182, neg: 0.287, neu: 0.575, pos: 0.138,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# 'Retro' Investing--Look Back to Get Ahead
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. News: Consumer Spending Rises Thanks to 'Cash for Clunkers' Boost
# compound: 0.6808, neg: 0.0, neu: 0.616, pos: 0.384,
# Rating Firms To Hold Off Downgrades Of Big Banks
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# `Dow 36,000' Gurus Hold to Their View Amid Downturn
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Housing market, consumer confidence improve while workers' wages languish: Compensation, up by 2.9%, trailed inflation pace in the latest 12 months
# compound: 0.7351, neg: 0.0, neu: 0.754, pos: 0.246,
# Accord on Debt Is Crucial, Dome Petroleum Says
# compound: -0.3612, neg: 0.263, neu: 0.737, pos: 0.0,
# Short-Term Rates Continue Sharp Drop As Federal Funds Charges Lead Decline
# compound: -0.4939, neg: 0.318, neu: 0.682, pos: 0.0,
# Volcker Plans to Join Wolfensohn Firm As Chairman and to Teach at Princeton
# compound: 0.296, neg: 0.0, neu: 0.845, pos: 0.155,
# GE Posts Rise Of 8.6% in Net For 3rd Quarter --- Sales Show 9.2% Gain; Drop In Taxes Cited, but Firm Labels Results `Good'
# compound: 0.1655, neg: 0.06, neu: 0.854, pos: 0.085,
# Budget Deficits: Only a Minor Crisis
# compound: -0.6249, neg: 0.506, neu: 0.494, pos: 0.0,
# A Lender of Last Resort? Russian Crisis Shows the Need
# compound: -0.6249, neg: 0.339, neu: 0.661, pos: 0.0,
# Theragenics Shares Fall 36% on Report Criticizing Outlook
# compound: -0.0772, neg: 0.234, neu: 0.561, pos: 0.206,
# Your Money Matters (A Special Report); The Journal Report Online
# compound: 0.4215, neg: 0.0, neu: 0.678, pos: 0.322,
# U.S. Jobless Claims Rose 11,000 Last Week; At Highest Level Since June, But Near Eight-Year Lows
# compound: -0.2023, neg: 0.107, neu: 0.893, pos: 0.0,
# Global Finance -- MoneyBeat / Market insight from WSJ.com: Fed Is Delaying Day of Reckoning
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Money Managers Aren't Yet Leaving Bonds for Stocks --- Balanced Funds Won't Move Into Equity Investments As Quickly as Expected
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Who Should've Been This President's Men? --- The Best and The Worst Of Reagan's Appointees
# compound: 0.0258, neg: 0.192, neu: 0.61, pos: 0.197,
# Treasurys, Bunds, Gilts Sell Off on Jobs Report
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Global Economy: China Pressured To Let Yuan Rise
# compound: -0.2263, neg: 0.192, neu: 0.808, pos: 0.0,
# Yield on 30-Year U.S. Debt Tumbles
# compound: -0.3612, neg: 0.333, neu: 0.667, pos: 0.0,
# Foreign Direct Investment in China Rises 17%
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dollar Gains Powered by Strong U.S. Growth; GDP Data Bolsters Market's Expectations for Higher Interest Rates
# compound: 0.8834, neg: 0.0, neu: 0.515, pos: 0.485,
# Production Fell For December, 3rd Time in Row --- Drop of 0.2% Raises Doubt About State of Recovery In National Economy
# compound: -0.5574, neg: 0.195, neu: 0.805, pos: 0.0,
# Corporate News: U.S. Solar Developer Withdraws Its IPO
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Central Bankers Receive Warning On Global Risks; Report Finds High Number Of Imbalances Threatening Economies Across the World
# compound: -0.765, neg: 0.341, neu: 0.603, pos: 0.056,
# Broaddus to Retire From Fed Bank Post
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stock Prices Advance on Strength In Bonds and Economic Optimism
# compound: 0.7717, neg: 0.0, neu: 0.544, pos: 0.456,
# The Outlook: Will Money Keep Economy on the Rise?
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# What Privatizing Social Security Would Mean for Your Retirement Plans
# compound: 0.34, neg: 0.0, neu: 0.789, pos: 0.211,
# Clinton Mulls Requiring More Notice of Layoffs --- Current Plant-Closing Law Has Proven to Be Flop, GAO Study Indicates
# compound: -0.34, neg: 0.118, neu: 0.882, pos: 0.0,
# Leading-Indicator Index Fell 0.5% in September
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Obama Chides Stimulus Critics
# compound: -0.296, neg: 0.423, neu: 0.577, pos: 0.0,
# U.S. News: Europe, Weak Economy Add to Pressure on Fed
# compound: -0.6249, neg: 0.389, neu: 0.611, pos: 0.0,
# Retail Sales Fall 0.4%, Hurt by GM Strike --- Despite Auto-Sector Drop, Outlays by Consumers Stay at Healthy Level
# compound: -0.0992, neg: 0.201, neu: 0.614, pos: 0.185,
# The Outlook: The Fed May Be Getting Into a Box
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Institutional Stock Market Commissions Seem to Be Leveling Off After Long Fall
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# $30 Billion Question
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Abreast of the market: Cyclical issues, last week's goat, lead stock market to solid gain
# compound: 0.6124, neg: 0.0, neu: 0.722, pos: 0.278,
# Stock Options May Be Curtailed
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S. News: Fed Nominees Back Policies to Reduce Unemployment
# compound: -0.4404, neg: 0.266, neu: 0.734, pos: 0.0,
# Back to Piecework: Many Companies Now Base Workers' Raises On Their Productivity --- Employees Who Lag Behind Stand to Lose Their Jobs In BankAmerica Division --- Bottom of the Fifth Quintile
# compound: -0.6249, neg: 0.15, neu: 0.85, pos: 0.0,
# The Experts: How to Deal With Rising Interest Rates
# compound: 0.4588, neg: 0.0, neu: 0.727, pos: 0.273,
# Weak Unions Create a Strong Economy
# compound: 0.3612, neg: 0.282, neu: 0.194, pos: 0.524,
# Gold Tumbles 3.1%; Silver Drops 4.9%; Strong Jobs Data Fuel Fears Fed Will Taper Stimulus
# compound: 0.128, neg: 0.147, neu: 0.681, pos: 0.173,
# Bond Prices Rise as Dealers, Investors Are Cheered by Rate Drop, Fed's Move
# compound: 0.296, neg: 0.128, neu: 0.671, pos: 0.201,
# Trading in Japan Stock-Index Futures Is Cleared for CBOT and Chicago Merc
# compound: 0.1027, neg: 0.0, neu: 0.887, pos: 0.113,
# Marooned: The Upwardly Mobile Find Hopes Dashed On Suburban Plateaus --- Gwinnett County, Ga., Was A Booming Way Station Until the Growth Stopped --- A New Industry: Pawn Shops
# compound: 0.5423, neg: 0.061, neu: 0.767, pos: 0.173,
# Leading Economic Indicators Show Rise In Sign Expansion Can Last to Year End
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Social Security Off-Budget: Expensive Idea
# compound: 0.34, neg: 0.0, neu: 0.625, pos: 0.375,
# World-Wide
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# TLC Agrees to Buy Laser Vision For Stock Valued at $98.7 Million
# compound: 0.6908, neg: 0.0, neu: 0.573, pos: 0.427,
# Ask David Wessel
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stock Market and GDP Both Fall Short as Bellwethers
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Letters to the Editor: Balancing Compassion and Profit
# compound: 0.7096, neg: 0.0, neu: 0.504, pos: 0.496,
# In Retail-Sector Stocks, Don't Buy Wholesale
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Home Prices Must Fall Far to Be In Sync With Rents
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Infosys to Set Up Office in China's Dalian
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Individual Investors Look to the 'Frontier' in Quest for Returns; One New Mutual Fund Invests in Bonds of Less-Developed Nations; Some Advisers Say Ride in These Markets Could Be Rough
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bond Prices Rise on Forecasts That Fed Will Push Rates Down to Spur Economy
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dow Industrials Finish 1st Half With 7.7% Gain
# compound: 0.5267, neg: 0.0, neu: 0.673, pos: 0.327,
# WEEKEND JOURNAL; TV Review: America Unguarded
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Oil Firms, Tanker Owners Renew Debate Over Amount Each Should Pay in Oil Spill
# compound: -0.1027, neg: 0.097, neu: 0.903, pos: 0.0,
# IBM Outlines New York Area Staff Cutbacks --- Sharp Job Reductions Set As the Company Clings To No-Layoff Policy
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Spotting Some 'Buys' in Tokyo's Stock Market Sell-Off
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# It's Your Money
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# West Germany's Central Bank Cuts Key Rate --- Little Impact Is Expected On Currency Markets Or Nation's Economy
# compound: -0.296, neg: 0.115, neu: 0.885, pos: 0.0,
# Stock Futures Close Higher
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Gold's Fate May Rest With Fed
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Let Student Loans Work for Students
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# White House Rejects Notion of Adding to Stimulus
# compound: -0.4939, neg: 0.314, neu: 0.686, pos: 0.0,
# Bond Yields Plunge Amid Falling Rates World-Wide; Declines, Slack Investment By Business Fuel Concerns Over a Global Slowdown
# compound: -0.1531, neg: 0.091, neu: 0.909, pos: 0.0,
# Abreast of the market: Wall Street still has the jitters despite first half's surge
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Government Bond Prices Edge Lower In Quiet Trading as Corporates Gain
# compound: 0.296, neg: 0.151, neu: 0.616, pos: 0.233,
# Union Walks Out Against Guilford Over Work Rules
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Last month's sales of existing homes increased by 1.9%
# compound: 0.2732, neg: 0.0, neu: 0.792, pos: 0.208,
# Bond Giant Pimco Buys Treasurys in Recent Weeks
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# More Job Cuts Urged for France And Germany --- McKinsey Suggests Moves Are Needed If Industries Are to Boost Efficiency
# compound: 0.4062, neg: 0.1, neu: 0.689, pos: 0.211,
# Futures Markets: Recent Rally in Platinum, Gold Prices Jumps the Tracks Amid Profit-Taking
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Jobs, Jobs, Jobs (Fibs, Fibs, Fibs)
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# British Air Is Offering Big Discounts, Raising Prospect of a Fall Fare War
# compound: -0.4019, neg: 0.242, neu: 0.621, pos: 0.137,
# The Tsunami Aftermath: Next Challenge For Survivors: Stress Disorder
# compound: -0.6369, neg: 0.43, neu: 0.469, pos: 0.102,
# Starwood to Buy LNR Property
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Fed Stays the Course on Bond Buying; Officials Leave Investors on Tenterhooks About When They Will Wind Down Program
# compound: -0.0516, neg: 0.062, neu: 0.938, pos: 0.0,
# College Try: U.S. Gets Tough On Failure to Repay Student Loans; Education Department Wields Heavy Hand, Critics Say, In Some Hard-Luck Cases; No Breaks in Bankruptcy Court
# compound: -0.6124, neg: 0.267, neu: 0.64, pos: 0.093,
# Dollar Declines In Face of Lower Interest Rates
# compound: 0.2023, neg: 0.196, neu: 0.536, pos: 0.268,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Regulators Give Passing Grade to Wells Fargo Plan on Theoretical Bankruptcy; Fed Says Big U.S. Bank Has Credible Plan in Case of Bankruptcy
# compound: 0.25, neg: 0.0, neu: 0.917, pos: 0.083,
# Bias Cited in College Lending
# compound: -0.1027, neg: 0.259, neu: 0.741, pos: 0.0,
# Bids & Offers
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Ahead of the Tape
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Hot Topic: Getting Into Harvard
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Asian Report: Taiwan's Economy Accelerates; China Proceeds on Space Program --- A Wall Street Journal News Roundup
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Personal Income Rose Strong 0.9% In September --- Consumer Spending Climbed 1.4%, Indicating Economy Is Likely to Keep Growing
# compound: 0.6124, neg: 0.0, neu: 0.773, pos: 0.227,
# MetLife: Low Rates Won't Dent Earnings
# compound: -0.2732, neg: 0.296, neu: 0.704, pos: 0.0,
# Currency Traders Face Bumpy Ride As Questions on Rates, EU Hit Market
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Euro Strengthens, European Stocks Retreat Despite Inflation Data; Euro-Zone CPI Data Steps Up Pressure on European Central Bank
# compound: 0.3818, neg: 0.1, neu: 0.682, pos: 0.218,
# Longer-Dated Treasury Issues May Bear Brunt of a Rate Cut
# compound: -0.0772, neg: 0.193, neu: 0.642, pos: 0.165,
# Letters to the Editor: Real and Nominal Borrowing Costs
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bond Prices Fall Slightly, Rates Finish Little Changed After Wednesday's Rally
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Congress Should Put Trade On the Fast Track
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Hot Topic: The Wages of Politics
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The 10-Point.; A personal, guided tour to the best scoops and stories every day in The Wall Street Journal, from Editor in Chief Gerard Baker.
# compound: 0.6369, neg: 0.0, neu: 0.846, pos: 0.154,
# India Rupee at One-Week Low
# compound: -0.2732, neg: 0.344, neu: 0.656, pos: 0.0,
# Bruising Quarter for Bond Fund Managers; Large Funds Posted Losses in Quarter
# compound: -0.4019, neg: 0.197, neu: 0.803, pos: 0.0,
# Heard on the Street: How High Will Low Interest Rates Push Stock Prices?
# compound: 0.2263, neg: 0.13, neu: 0.683, pos: 0.186,
# Small-Stock Indexes Lose Ground On Profit Warnings, Oil Prices
# compound: -0.25, neg: 0.355, neu: 0.435, pos: 0.21,
# Nasdaq Aims to Pay Up In SEC Facebook Probe
# compound: -0.1027, neg: 0.149, neu: 0.851, pos: 0.0,
# Relying on IRS Call-In Tax Service Could Be an Invitation to Trouble
# compound: -0.4019, neg: 0.197, neu: 0.803, pos: 0.0,
# Mexico Charts Shifts in Relations With U.S. --- Mexico's Fox Plans For Broader Policy On U.S. Immigration
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Oil Futures Fall as Crude Market Waits for Fed Announcement; Expectations Abound That the Fed will Begin Scaling Back QE Program in Near Future
# compound: -0.5719, neg: 0.139, neu: 0.861, pos: 0.0,
# Dollar Rises Against Yen Despite Data
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Refinancing Rocks Bond Market --- Homeowners Hunting for Deals On Mortgage Rates Unleash Era Of Volatility and Trading Losses
# compound: -0.4019, neg: 0.13, neu: 0.87, pos: 0.0,
# Abreast of the market: Jitters over profits could upset stock market
# compound: 0.0772, neg: 0.179, neu: 0.621, pos: 0.2,
# Stocks Decline in Slower Trading As Profit-Taking Ends 3-Day Rally
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# World Business (A Special Report) --- Report Card: Rating Risk in the Hot Countries --- How Two Firms Gauge Investment Safety
# compound: 0.5267, neg: 0.082, neu: 0.703, pos: 0.215,
# Speaking of Business: Among Economists, Eclecticism Is All the Rage
# compound: -0.5574, neg: 0.286, neu: 0.714, pos: 0.0,
# Clustering Can Diversify a Real-Estate Portfolio
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stock Market Needs Anti-Dumping Rules
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Business and Finance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# ...
# compound: 0.0951, neg: 0.0, neu: 0.836, pos: 0.164,
# WASHINGTON INVESTING: Some Battered Area Stocks Rebounded Last Month
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Fed Chairman Sees Signs Economy Is Stabilizing: Greenspan Says Gulf Will Have Major Iinpac
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# White House Plan to Bolster FDIC Dealt New Setbacks
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# New Players Join the Takeover Game; Well-Financed Companies, Not Raiders, Call the Shots as the Acquisition Field Changes
# compound: 0.296, neg: 0.0, neu: 0.885, pos: 0.115,
# Faster Chips Aren't Better, AMD Insists
# compound: -0.3412, neg: 0.325, neu: 0.675, pos: 0.0,
# Court Realty Section In Fairfax Is Doing Land-Office Business; Inundated Agency Asks County for Help
# compound: 0.4019, neg: 0.0, neu: 0.838, pos: 0.162,
# Effects of Surtax Discounted
# compound: 0.0516, neg: 0.0, neu: 0.714, pos: 0.286,
# Jobless Rate Dips To 5.8%: But Jobs Are Scarcer; Prices Rise
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Electronics Spark Strong Stock Rebound: Trading Volume Expands
# compound: 0.6808, neg: 0.0, neu: 0.431, pos: 0.569,
# As Rates Peak, Money Funds Pique; Returns Near 5% as Fed Hikes Add Up
# compound: -0.2732, neg: 0.139, neu: 0.861, pos: 0.0,
# A 2 2 FRIDAY, MARCH 3, 19 7 8
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Dow Off 5; NYSE Breaks Trading Volume Record
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# More About The Man of Independence: HARRY S TRUMAN: A Life By Robert...
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Proxmire Urges LBJ to Reverse Tax Stand: Business Leaders Foresee Expansion
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# County to Weigh Taxi Fare Increase; Higher Prices for Gas Prompt Push
# compound: 0.3182, neg: 0.0, neu: 0.827, pos: 0.173,
# Defense: Beware the Global Tidal Wave
# compound: 0.128, neg: 0.0, neu: 0.769, pos: 0.231,
# Growing Boom Called Dangerous by Okun: Excessive Growth Rate Personal Income Hops Prom
# compound: 0.0516, neg: 0.178, neu: 0.575, pos: 0.247,
# Industrials Lead Retreat in Stock Market: Trading Is Only Moderate
# compound: 0.2023, neg: 0.0, neu: 0.833, pos: 0.167,
# Prices Close Uneven on Thin Turnover: 3-Day Advance Is Halted
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# <EI|c toasliinglon fJost
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Soaring Mightily Into Retirement; At Justice Department Farewell, a Salute to the Lighter Side of Ashcroft
# compound: 0.5267, neg: 0.0, neu: 0.805, pos: 0.195,
# The Long Haul of Rep. Gus Hawkins; At 83, the Steady Champion of Civil Rights Is Retiring From a Battle That Won't End
# compound: 0.3182, neg: 0.098, neu: 0.755, pos: 0.147,
# Financial Controls Faulted in Schools, Medicaid, Tax Office
# compound: -0.34, neg: 0.255, neu: 0.745, pos: 0.0,
# New Jobless Claims Increase by 39,000; Report Is Latest Sign of Troubled Recovery
# compound: -0.1779, neg: 0.184, neu: 0.675, pos: 0.141,
# Rails, Steels, Rubbers, Utilities Sag
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Digest
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Load Powers Are Tightest Since 1957
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# C6 SUNDAY, MAY 16,	1982
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Q&A By Paul Blustein
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Would the Fed Be to Blame For Recession?; Central Bank Officials Know They Are Vulnerable
# compound: -0.5106, neg: 0.249, neu: 0.751, pos: 0.0,
# Prime Rate Rise Dampens Wall Street: Prime Rate Rise Dampens Wall Street
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# A Bond Guaranteed to Beat Inflation
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Congress Speeds Passage of Aid To Unemployed: Hill Speeds Passage of Aid to Unemployed
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Virginia Tech Suspect Served as Victim's Mentor on Campus
# compound: -0.296, neg: 0.216, neu: 0.784, pos: 0.0,
# Housing Strong For Last Month: Housing at 2 Million Annually
# compound: 0.5106, neg: 0.0, neu: 0.708, pos: 0.292,
# Getting Bigger at the Box Office; A 25-Cent Increase Brings Ticket Prices to $7.25 at Many Area Theaters
# compound: 0.3182, neg: 0.0, neu: 0.874, pos: 0.126,
# Reports Reverse Upward Momentum
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Chemicals Also Advance
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# JP Foodservice has an appetite for growth
# compound: 0.6289, neg: 0.0, neu: 0.493, pos: 0.507,
# Some Say Rate Cuts Are Just A Scratch; Analysts: Banks Not Following Fed Lead
# compound: -0.296, neg: 0.155, neu: 0.845, pos: 0.0,
# Anti-Inflation Tax on Sales Is Proposed
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stocks Churn To Small Gain: Steel Shares Gam Plus Margin Widens Gambling Stocks Up
# compound: 0.6808, neg: 0.0, neu: 0.682, pos: 0.318,
# 456,000 Jobs Added In March: Strong Employment Figures Help Send Interest Rates Higher
# compound: 0.8402, neg: 0.0, neu: 0.526, pos: 0.474,
# Funds That Show Power of Just One
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# BANK BILL AT A GLANCE
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Rio No Vacation for AOL; Firm Remains Also-Ran in Exploding Market
# compound: -0.296, neg: 0.18, neu: 0.82, pos: 0.0,
# Wholesale prices drop, calming inflation fears
# compound: -0.296, neg: 0.462, neu: 0.283, pos: 0.255,
# Fed Musi Decide ..  On	Aiili-lnflation	Step: News Analysis
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Strike Forecast: 'Absolutely Awful'
# compound: -0.5849, neg: 0.706, neu: 0.294, pos: 0.0,
# Expects Decline to Begin by Next Year: Baldrige Says Trade Deficit Should Decline by Next Year
# compound: -0.4019, neg: 0.153, neu: 0.847, pos: 0.0,
# Steels Lower In Generally Steady Trade
# compound: -0.296, neg: 0.306, neu: 0.694, pos: 0.0,
# Schaefer Orders 40-Hour Week
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Economic Growth Put At 5.5 Pct.; Upbeat Farm Estimate Boosts GNP Figure
# compound: 0.5994, neg: 0.0, neu: 0.671, pos: 0.329,
# Progress or Peril?; For seven months, The Post has explored what it means to be a black man in America. Two scholars respond to the stories -- and look to the future.
# compound: 0.4215, neg: 0.0, neu: 0.915, pos: 0.085,
# Tariff Cuts Extended To All GATT Nations
# compound: -0.296, neg: 0.268, neu: 0.732, pos: 0.0,
# States Discover That What Goes Around, Comes Around
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Md. Begins Crackdown On Insurance Form Fees
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Shades of Campaign Truth
# compound: 0.3182, neg: 0.0, neu: 0.566, pos: 0.434,
# Season's Sale Spree Reported Biggest in Nearly a Decade: U.S. Retailers Report Merry Sales Spree
# compound: 0.5423, neg: 0.0, neu: 0.788, pos: 0.212,
# GOP Says Maryland Democrats Raised State Pay Under a Veil
# compound: -0.1027, neg: 0.149, neu: 0.851, pos: 0.0,
# The Affluent Passing the Buck
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Mexico's Spreading Drug Stain; Mexican Cartels Expanding Role In Trafficking
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stocks Fall as Gasoline Demand Jumps, Bernanke Comments on Economy
# compound: -0.128, neg: 0.143, neu: 0.857, pos: 0.0,
# American Express to Convert To Bank Holding Company
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Tapping a Retirement Account Can Help or Hinder Home Buyer
# compound: 0.4019, neg: 0.0, neu: 0.748, pos: 0.252,
# The Washington Post (1974-Current file); Feb 3, 1988;
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# (T1)C IVnsIjington JJost
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Strauss Urges 'Toughest' Program on Wages, Prices
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Banks' Reserves Tighten; Loans Up
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Watt Street Prices Fall, Ignoring Carter's Speech
# compound: -0.4019, neg: 0.31, neu: 0.69, pos: 0.0,
# Bush's `Chain-Saw' Nightmare
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# AFL-CIO Sues to Bar U.S. Wage Penalty
# compound: -0.4588, neg: 0.333, neu: 0.667, pos: 0.0,
# Steel Hopes Spur Active Rally in Stocks: Electronic Issues Soar
# compound: 0.6705, neg: 0.0, neu: 0.593, pos: 0.407,
# GOP's Arkansas Foray Retreats in Confusion
# compound: -0.296, neg: 0.306, neu: 0.694, pos: 0.0,
# As Maine Goes . . .
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Market Shows Gains: Exchanges Report Short Interest Off
# compound: 0.6597, neg: 0.0, neu: 0.526, pos: 0.474,
# College Degree No Shield As More Jobs Are Slashed; In Far-Reaching Recession, Few Are Immune
# compound: -0.6077, neg: 0.352, neu: 0.54, pos: 0.108,
# Pocketbook Issues Play Well in N.J. Senate Race: Pocketbook Issues Focus In NJ. Race
# compound: 0.5423, neg: 0.0, neu: 0.727, pos: 0.273,
# Surprise Boom May Deepen A Recession: An Inflationary Bubble Could Wreck Guidelines
# compound: -0.5574, neg: 0.361, neu: 0.506, pos: 0.133,
# Stocks Again Skid; Trade Quiet
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Jobless Recovery Hobart Rowen
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Government, Industry Agree On Securities Insurance
# compound: 0.5719, neg: 0.0, neu: 0.46, pos: 0.54,
# FOR THE RECORD
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Mutual Funds Flat in Quarter; Lackluster Showing Contrasts With Gains Last Year
# compound: 0.34, neg: 0.0, neu: 0.821, pos: 0.179,
# Can China Lead a Recovery?; As American consumers struggle, some look east for a spending spark.
# compound: -0.1027, neg: 0.142, neu: 0.741, pos: 0.117,
# CDs, for a Return Guarantee; The Certificates Are Safe, but They Can Also Tie Up Money
# compound: 0.3506, neg: 0.0, neu: 0.79, pos: 0.21,
# SB A Counsel Hopes To Ease Tax Impact: The Small Business Tax Impact
# compound: 0.6486, neg: 0.0, neu: 0.654, pos: 0.346,
# Are We Running Out of Time for an Economic Lift?
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Let traders call the next bubble
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# 1976 Wage Pacts Held Key to Renewed Inflation
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# DIGEST DIGEST
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Average Drops $2.20 Average Drops $2.20
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Market Up As Volume Sets Mark
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Report Shows Deficit Diving to $116 Billion: CBO Forecasts Smallest Shortfall Since '81
# compound: -0.34, neg: 0.18, neu: 0.733, pos: 0.087,
# Wholesale Prices End Steep Rise: Wholesale Cost Index Ends 4-Month Climb
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Worries Depress Market: Dow Loses 11.89 More In Decline
# compound: -0.8074, neg: 0.58, neu: 0.42, pos: 0.0,
# In Order to Form a More Perfect Billing System
# compound: 0.6115, neg: 0.0, neu: 0.637, pos: 0.363,
# No Stomach For the 'Stimulus'
# compound: -0.296, neg: 0.355, neu: 0.645, pos: 0.0,
# Senate Debates Priorities For `Peace Dividend'; Measures Indicate Political Nature of Issue
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Big Inventory Cuts Help Stocks Forge Broad-Based Rally
# compound: 0.128, neg: 0.202, neu: 0.55, pos: 0.248,
# Fed Chairman Endorses Budget Agreement
# compound: 0.6808, neg: 0.0, neu: 0.349, pos: 0.651,
# MCA, Sony: Why mergers didn't work
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Late Buying Rescues Market From Big Dip
# compound: 0.3182, neg: 0.0, neu: 0.723, pos: 0.277,
# Cutbacks 'Crushing' Blacks: Blacks' Economic State Reported as Disastrous
# compound: -0.5994, neg: 0.328, neu: 0.672, pos: 0.0,
# THE WASHINGTON POST Sunday, November 12,1978
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Annan's Contacts With Firm Probed; Oil-for-Food Panel Is Examining Son's Links With Company
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Energy Costs Spur Increase in Producer Prices; Analysts Say Recovery Not Threatened
# compound: 0.7077, neg: 0.0, neu: 0.567, pos: 0.433,
# A Shrinking Burden; Pain Withheld: For Many, Tax Time Is Losing Some of Its Bite
# compound: -0.8316, neg: 0.444, neu: 0.556, pos: 0.0,
# Stocks Pounded Again; Rally Cuts Losses: Dow Finds Support at 614
# compound: -0.296, neg: 0.314, neu: 0.513, pos: 0.173,
# Bouyant Real Estate Market Forecast for Rest of Year: Realty Dialogues With Bernard C. Meltzer
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Brimmer Urges New Controls On Multinational Bank Activity
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# When Ford Was in the White House
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Virginia: Thank You, Asia; The Slump Overseas May Be Benefiting the State's Consumers
# compound: 0.3612, neg: 0.0, neu: 0.828, pos: 0.172,
# Nation's Money Supply Posts a Sharp Increase
# compound: 0.3182, neg: 0.0, neu: 0.685, pos: 0.315,
# Lump Sums on Way Out
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Most Moves Narrow 3Izpst Mcrves
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Book Report
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# U.S.-Led Campaign Fails to Shore Up Value of the Dollar; Decline of Currency Prompts Broad Sell-Off in Stocks, Bonds
# compound: -0.1027, neg: 0.126, neu: 0.766, pos: 0.108,
# Dow Rises 8.67 In Busiest Day So Far This Year: Blue Chips Lead Surge
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Despite Tight Times, PACs Galore
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# ...---- ^----- I----  .åÈ
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Housing Starts Grow, Raising Inflation Fears: Economists See Another Interest Rate Increase
# compound: 0.3612, neg: 0.164, neu: 0.526, pos: 0.31,
# Profits Often Evasive In Stock Mart Rallies Greer, Philip
# compound: 0.4404, neg: 0.0, neu: 0.734, pos: 0.266,
# Fauntroy, Hodges Exchange Angry Letters on Bank's Fate
# compound: -0.5106, neg: 0.32, neu: 0.68, pos: 0.0,
# Treasury Sets Goal For Debt Paydown; $221 Billion Will Be Cut This Year
# compound: -0.4215, neg: 0.28, neu: 0.61, pos: 0.11,
# Coppers, Steels in Van
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Anxiety Attacks
# compound: -0.5574, neg: 1.0, neu: 0.0, pos: 0.0,
# Confidence in Reagan on Deficit Declines: Poll Finds Greater Trust in ...
# compound: 0.7506, neg: 0.136, neu: 0.404, pos: 0.46,
# Congress's Dismal Grades
# compound: -0.6124, neg: 0.667, neu: 0.333, pos: 0.0,
# Potential City Deficit Bigger Than Mayor Expected: Mayor Says Big Potential Deficit Looms
# compound: -0.7184, neg: 0.412, neu: 0.588, pos: 0.0,
# Lack of Lifeline May Give Ford a Boost
# compound: 0.1027, neg: 0.23, neu: 0.5, pos: 0.27,
# Unemployment Rate Declines to 5.8 Percent: Unemployment Falls To Lowest Level Since Mid-1979
# compound: -0.8126, neg: 0.457, neu: 0.543, pos: 0.0,
# Salomon Sounds a Wary Note on the Economy
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Stocks Again Ease; Select Issues Spurt
# compound: 0.3612, neg: 0.0, neu: 0.667, pos: 0.333,
# IMF Shift to Eastern Europe Stirs Discontent in Third World
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# The Great Terror; A massive new history of Hitler's tyranny.
# compound: 0.1779, neg: 0.234, neu: 0.483, pos: 0.283,
# The Puzzling Economy
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Taking his jobs message on the road; Obama starts tour with visit to struggling Pa. community
# compound: -0.4215, neg: 0.157, neu: 0.843, pos: 0.0,
# Read 'em and Weep; Cardholders See Rates Rise Based on Other Debts
# compound: -0.5719, neg: 0.252, neu: 0.748, pos: 0.0,
# Economy's Ills To Be Studied By Committee: Aim at Reserve Board
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Circulate a Mistake: Fed Must Decide Fate of Flawed $50 Bills
# compound: -0.34, neg: 0.211, neu: 0.789, pos: 0.0,
# Angry Shareholders Urge Sale of Baltimore BancorpBank
# compound: -0.5106, neg: 0.355, neu: 0.645, pos: 0.0,
# Stocks Rise for Third Straight Session: Better Sales Help Autos
# compound: 0.7579, neg: 0.0, neu: 0.483, pos: 0.517,
# Sawyer Sees Strong Economy For 2 Years, Truce or Not
# compound: 0.5106, neg: 0.0, neu: 0.708, pos: 0.292,
# Oil's losses are airlines' gains
# compound: -0.0772, neg: 0.333, neu: 0.37, pos: 0.296,
# Full Senate to vote on Bernanke; PANEL ADVANCES RENOMINATION Sharp debate hints at difficult confirmation
# compound: -0.3612, neg: 0.152, neu: 0.848, pos: 0.0,
# Reinventing Opportunities
# compound: 0.3818, neg: 0.0, neu: 0.278, pos: 0.722,
# Stocks Rise On News of Auto Output: Dow Climbs 6.85 Points Auto Group ...
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,

# %%
# capture only those that are significantly positive or negative...
# this prints all headlines
vader_list = []

for title in df.headline:
    ss = sid.polarity_scores(title)
    vader_list.append(ss)

# confirmed - returns dataframe with vader_sent correctly aligned with headlines (iffy when adding new column as list)
df['vader_sent'] = vader_list
df.info()

# %% [markdown]
# # Global News Articles - Topic Modeling + Sentiment

# %% [markdown]
# Amazon has separate retail websites for the United States, the United Kingdom and Ireland, France, Canada, Germany, Italy, Spain, Netherlands, Australia, Brazil, Japan, China, India, and Mexico.

# %% [markdown]
# ### Data - Load

# %% [markdown]
# #### Load via Iterator

# %%
# can use 'chunksize=X' or 'iterator=True' along with 'read.get_chunk(X)' to get exactly desired chucnk 
reader = pd.read_csv('~/ds/data/nlp/news-week-aug24.csv', iterator=True, encoding='UTF-8') # , encoding='latin-1',

# %%
df_news = reader.get_chunk(100000)
df_news.sample(3)
# Out:
#        publish_time         feed_code  \
# 39867  201708240449    w3-nzherald-nz
# 6193   201708240037        w3-naslovi
# 47557  201708240604  w3-zetaestaticos
#
#                                               source_url  \
# 39867  http://www.nzherald.co.nz/nz/news/article.cfm?...
# 6193   http://www.naslovi.net/2017-08-24/blic-sport/z...
# 47557  http://www.elperiodicodearagon.com/noticias/ar...
#
#                                            headline_text
# 39867  More than a pretty face: The place of young wo...
# 6193   Blic sport: Zaostali meč Superlige: Radnički p...
# 47557  Villar de los Navarros : la batalla narrada po...

# %% [markdown]
# #### Load all directly

# %%
df_news = pd.read_csv('~/ds/data/nlp/news-week-aug24.csv', encoding='UTF-8')

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1398431 entries, 0 to 1398430
# Data columns (total 4 columns):
# publish_time     1398431 non-null int64
# feed_code        1398431 non-null object
# source_url       1398431 non-null object
# headline_text    1397447 non-null object
# dtypes: int64(1), object(3)
# memory usage: 42.7+ MB

# %% [markdown]
# ### Data - Language detection (using textblob) -- Don't run, takes days

# %%
# takes a long time to run...
# df_news1['language'] = df_news1['headline_text'].apply(lambda x: TextBlob(x).detect_language())
# df_news1.sample(3)

# %%
# reads in all AMZN and 'en' language filtered articles from Global News dataset
df_allennews = pd.read_pickle('~/ds/data/nlp/news-week-aug24_lang.pkl')

# %%
# quick EDA
df_allennews.info()

# %%
# load from pkl
df_articles_en = pd.read_pickle('tweet_data/en_articles.pkl')
df_articles_en = df_articles_en[df_articles_en['language'] == 'en']

# %% [markdown]
# ### Data - AMZN Filter

# %%
#Removes front and end punctuation, makes all lower case, removes empty strings.
def clean_news(article):    
    return ' '.join([w.lower().strip().rstrip(string.punctuation)\
        .lstrip(string.punctuation).strip()\
        for w in article.split()\
        if w.strip().rstrip(string.punctuation).strip()])

# function to force to 'None' if error in cleaning on following step
def try_clean(text):
    try:
        w = clean_news(text)
        return(w)
    except:
        return(None)

# clean the headlines
pre_filter = []

for x in df_news.headline_text:
    pre_filter.append(try_clean(x))
    
len(pre_filter)
# Out:
# 1398431

# %%
# return list of indicies with 'None' values (for whatever reason) that we will drop from 'df_news'
drop_inds = []
for ind, x in enumerate(pre_filter):
    if x is None:
        drop_inds.append(ind)
        
# drop from df_news
df_news = df_news[~df_news.index.isin(drop_inds)]
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1397447 entries, 0 to 1398430
# Data columns (total 4 columns):
# publish_time     1397447 non-null int64
# feed_code        1397447 non-null object
# source_url       1397447 non-null object
# headline_text    1397447 non-null object
# dtypes: int64(1), object(3)
# memory usage: 53.3+ MB

# %%
# below separates 'None'-filtered list from df, which is not ideal as it is repeated a step... but it works.
pre_filter2 = [x for x in pre_filter if x is not None]

# apply Amazon filter
filter_list = ['bezos','amazon','amzn','hq2', 'alexa', 'audible', 'zappos','goodreads', 'jeffbezos', 'whole foods']

filtered_indys = []

for x in filter_list:
    for indy, y in enumerate(pre_filter2):    # could probably also use .map or .apply and lambda here to work
        if x in y:                           # directly on the DF
            filtered_indys.append(indy)

df_amznnews = df_news.iloc[filtered_indys]
df_amznnews.sample(10)
# Out:
#          publish_time           feed_code  \
# 1004784  201708290228      w3-nydailynews
# 936197   201708282003         w3-usatoday
# 1138529  201708291720    w3-miaminewtimes
# 419043   201708251825           w3-nasdaq
# 1143925  201708291745  w3-tech-fanpage-it
# 427015   201708251904         w3-deadline
# 1026335  201708290530     w3-frenchweb-fr
# 478089   201708260010        w3-wordpress
# 1360181  201708301653  w3-us-blastingnews
# 6761     201708240040       w3-uk-reuters
#
#                                                 source_url  \
# 1004784  http://www.nydailynews.com/new-york/nyc-shoppe...
# 936197   https://www.usatoday.com/story/tech/reviewedco...
# 1138529  http://www.miaminewtimes.com/restaurants/whole...
# 419043   http://www.nasdaq.com/article/amazon-strikes-a...
# 1143925  http://tech.fanpage.it/amazon-attenzione-ai-pr...
# 427015   http://deadline.com/2017/08/roy-price-amazon-f...
# 1026335  http://www.frenchweb.fr/numbers-combien-amazon...
# 478089   https://soundbooksfuntoys.com/2017/08/25/some-...
# 1360181  http://us.blastingnews.com/tech/2017/08/alexa-...
# 6761     http://uk.reuters.com/article/us-whole-foods-m...
#
#                                              headline_text
# 1004784  New York shoppers thrilled with Whole Foods pr...
# 936197   Get an Echo Dot alternative&mdash;and 3 months...
# 1138529  Whole Foods Market Drop Prices After Amazon Pu...
# 419043   Amazon Strikes a Blow at Rivals with Whole Foo...
# 1143925  Amazon, attenzione ai profili Instagram che of...
# 427015   Comment on Roy Price Says Amazon Will Do Fewer...
# 1026335  [Numbers] Combien Amazon a-t-il dépensé en fra...
# 478089   Some SNES Classic Pre-Orders Delayed, But Not ...
# 1360181  Alexa and Cortana integration, product of Amaz...
# 6761     FTC clears Amazon.com acquisition of Whole Foo...

# %%
# convert 'publish_time' to datetime format
df_amznnews['publish_time'] = df_amznnews['publish_time'].astype(str)
df_amznnews['publish_time'] = pd.to_datetime(df_amznnews['publish_time'], format='%Y%m%d%H%M')
df_amznnews.info()
# the big 'Y' was key to making the 'to_datetime()' work
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6459 entries, 769 to 1397573
# Data columns (total 4 columns):
# publish_time     6459 non-null datetime64[ns]
# feed_code        6459 non-null object
# source_url       6459 non-null object
# headline_text    6459 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 252.3+ KB
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ##### Previous impl (separate out only headline list)

# %%
# changes text data to np array and forces Unicode format that will be accepted into next step
articles = df_news1.headline_text.values.astype('U')

# build list of cleaned text
pre_filter = []

for x in articles:
    w = clean_news(x)
#     z = word_tokenize(w)
    pre_filter.append(w)


# apply Amazon filter
filter_list = ['bezos','amazon','amzn','hq2', 'alexa', 'audible', 'zappos','goodreads', 'jeffbezos', 'whole foods']

filtered_list = []

for x in filter_list:
    for y in pre_filter:
        if x in y:
            filtered_list.append(y)

print(len(filtered_list))
print(filtered_list[:3])
# Out:
# 549

# %% [markdown]
# ### Sentiment on AMZN Headlines

# %% [markdown]
# Options for analysis:
# - compare Amazon twitter sentiment vs article sentiment
# - compare Amazon article sentiment with all article sentiment

# %% [markdown]
# #### AMZN Articles - Textblob Sentiment

# %%
textblob_list = []
for title in df_amznnews.headline_text:
    x = TextBlob(title).sentiment.polarity
    textblob_list.append(x)

df_amznnews['textblob_sent'] = textblob_list
df_amznnews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6459 entries, 769 to 1397573
# Data columns (total 5 columns):
# publish_time     6459 non-null datetime64[ns]
# feed_code        6459 non-null object
# source_url       6459 non-null object
# headline_text    6459 non-null object
# textblob_sent    6459 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 302.8+ KB
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# df_amznnews[df_amznnews.textblob_sent != 0]

# %% [markdown]
# #### AMZN Articles - Vader Sentiment (nltk)

# %%
sid = SentimentIntensityAnalyzer()

vader_list = []

for title in df_amznnews.headline_text:
    ss = sid.polarity_scores(title)
    vader_list.append(ss)

# confirmed - returns dataframe with vader_sent correctly aligned with headlines (iffy when adding new column as list)
df_amznnews['vader_sent'] = vader_list


# Create separate columns for each Vader Sentiment key.
vs_neg_list = [x['neg'] for x in df_amznnews.vader_sent]
vs_neu_list = [x['neu'] for x in df_amznnews.vader_sent]
vs_pos_list = [x['pos'] for x in df_amznnews.vader_sent]
vs_compound_list = [x['compound'] for x in df_amznnews.vader_sent]

# Add lists to dataframe.
df_amznnews['vs_neg'] = vs_neg_list
df_amznnews['vs_neu'] = vs_neu_list
df_amznnews['vs_pos'] = vs_pos_list
df_amznnews['vs_compound'] = vs_compound_list

# Show it off.
df_amznnews.info()
# Out:
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6459 entries, 769 to 1397573
# Data columns (total 10 columns):
# publish_time     6459 non-null datetime64[ns]
# feed_code        6459 non-null object
# source_url       6459 non-null object
# headline_text    6459 non-null object
# textblob_sent    6459 non-null float64
# vader_sent       6459 non-null object
# vs_neg           6459 non-null float64
# vs_neu           6459 non-null float64
# vs_pos           6459 non-null float64
# vs_compound      6459 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 555.1+ KB
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### LDA Topic Modeling on AMZN docs

# %% [markdown]
# #### First pass

# %% [markdown]
# - Can do sentiment analysis here (inclusion / exclusion of previously filtered words is fine)

# %%
df_amznnews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6459 entries, 769 to 1397573
# Data columns (total 10 columns):
# publish_time     6459 non-null datetime64[ns]
# feed_code        6459 non-null object
# source_url       6459 non-null object
# headline_text    6459 non-null object
# textblob_sent    6459 non-null float64
# vader_sent       6459 non-null object
# vs_neg           6459 non-null float64
# vs_neu           6459 non-null float64
# vs_pos           6459 non-null float64
# vs_compound      6459 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 555.1+ KB

# %%
for x in df_amznnews.headline_text[:4]:
    print(x)
# Out:
# Jeff Bezos's Rivals Are Teaming Up to Take on Amazon
# Seattle Council Member Say Jeff Bezos Should Improve Working Conditions for 'Gig Economy' Contractors
# Seattle councilmember calls on Jeff Bezos to push for better 'gig economy' working conditions
# Trump rips everyone in Arizona speech -- including Amazon, again, and Bezos-owned Washington Post

# %%
# Tokenize / Vectorize w CountVectorizer
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=3,
                                ngram_range=(1,1),
                                max_features=5000,
                                stop_words='english')
tf = tf_vectorizer.fit_transform(df_amznnews.headline_text)

# %%
# define model (lda) and model parameters, fit model to vectorized data

n_components = 10

lda = LatentDirichletAllocation(n_components=n_components, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx), " ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
#         print (" ".join([feature_names[i]
#                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, vocab, n_components)
# Out:
# Topic 0: amazon foods deal ftc takeover gets approval acquisition key federal
# Topic 1: amazon alexa cortana microsoft new google shopping music voice comment
# Topic 2: amazonas alexandre para governador amazonino lacazette arsenal total eleito da
# Topic 3: amazon season today transparent renews sale analyst big 14 alexandria
# Topic 4: foods amazon prices monday cut cuts lower like price grocery
# Topic 5: amazon la market en foods best el open 2017 se
# Topic 6: amazon echo foods cheaper fresh milk just apple room multi
# Topic 7: amazon farm takes com 10 amzn foods food 99 high
# Topic 8: amazon foods prime day members amzn 43 discounts deal percent
# Topic 9: alexander alexandra zverev die won alexandru amazon gauland latest block

# %% [markdown]
# #### Filter out filter words... (don't confuse LDA)

# %%
# COPIED FROM ELSEWHERE
#Removes front and end punctuation, makes all lower case, removes empty strings.
def clean_news(article):    
    return ' '.join([w.lower().strip().rstrip(string.punctuation)\
        .lstrip(string.punctuation).strip()\
        for w in article.split()\
        if w.strip().rstrip(string.punctuation).strip()])

# function to force to 'None' if error in cleaning on following step
def try_clean(text):
    try:
        w = clean_news(text)
        return(w)
    except:
        return(None)

# clean the headlines
clean_amzn_list = []

for x in df_amznnews.headline_text:
    clean_amzn_list.append(try_clean(x))
    
len(clean_amzn_list)
# Out:
# 6459

# %%
# this is nasty - but it works and cheap on this preprocessed data...
def no_freqs(headline):
    no_freq1 = re.sub('amazon','',headline)
    no_freq2 = re.sub('jeff bezos','',no_freq1)
    no_freq3 = re.sub('bezos','',no_freq2)
    no_freq4 = re.sub('amzn','',no_freq3)
    no_freq5 = re.sub('hq2','',no_freq4)
    no_freq6 = re.sub('alexa','',no_freq5)
    no_freq7 = re.sub('audible','',no_freq6)
    no_freq8 = re.sub('zappos','',no_freq7)
    no_freq9 = re.sub('goodreads','',no_freq8)
    no_freq10 = re.sub('jeffbezos','',no_freq9)
    no_freq11 = re.sub('whole foods','',no_freq10)
    return (no_freq11)

# %%
# filter out key words
double_filtered_list = [no_freqs(x) for x in clean_amzn_list]
double_filtered_list[:5]
# Out:
# ["'s rivals are teaming up to take on ",
#  'seattle council member say  should improve working conditions for gig economy contractors',
#  'seattle councilmember calls on  to push for better gig economy working conditions',
#  'trump rips everyone in arizona speech including  again and -owned washington post',
#  'president trump goes after  and  on twitter']

# %%
# Tokenize / Vectorize w CountVectorizer
tf_vectorizer = CountVectorizer(max_df=0.98, min_df=5,
                                ngram_range=(1,3),
                                max_features=500,
                                stop_words='english')
tf = tf_vectorizer.fit_transform(double_filtered_list)

# %%
# define model (lda) and model parameters, fit model to vectorized data

n_components = 6

lda = LatentDirichletAllocation(n_components=n_components, max_iter=15,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=42)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx), " ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
#         print (" ".join([feature_names[i]
#                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10
display_topics(lda, vocab, n_components)
# Out:
# Topic 0: prices monday lower lower prices cheaper shopping
# Topic 1: deal cortana new takes microsoft walmart
# Topic 2: grocery echo cheaper fresh farm farm fresh
# Topic 3: prices cuts prime cut price cut prices
# Topic 4: day la slashes 43 slashes prices prices 43
# Topic 5: nder gets takeover approval key federal

# %% [markdown]
# # Presentation

# %% [markdown]
# ### Sentiment Graphs

# %%
# ARTICLE sentiment over time
# df_amznnews.plot(df_amznnews['publish_time'], df_amznnews['textblob_sent'])
df_amznnews.plot('publish_time', 'textblob_sent')
plt.xticks(rotation=45)
plt.show()

# %%
dates = matplotlib.dates.date2num(list(df_amznnews.publish_time))
plt.xticks(rotation=45)
plt.title('Sentiment of "Amazon" Headlines')
plt.xlabel('Date')
plt.ylabel('Sentiment Score')
plt.tight_layout()
plt.plot_date(dates, df_amznnews.textblob_sent)
plt.savefig('Visuals/all_sents.png', dpi=900, bbox_inches='tight');

# %%
df_amznnews_dti = df_amznnews.set_index('publish_time')
df_amznnews_dti_re = df_amznnews_dti['textblob_sent'].resample('1H').sum()
# df_amznnews_dti.info()
df_amznnews_dti_re
# Out:
# publish_time
# 2017-08-24 00:00:00    16.940512
# 2017-08-24 01:00:00    14.502128
# 2017-08-24 02:00:00     9.511364
# 2017-08-24 03:00:00     5.670833
# 2017-08-24 04:00:00     3.439394
# 2017-08-24 05:00:00     2.412500
# 2017-08-24 06:00:00     0.766667
# 2017-08-24 07:00:00     3.557576
# 2017-08-24 08:00:00     4.010417
# 2017-08-24 09:00:00     1.400000
# 2017-08-24 10:00:00     2.600000
# 2017-08-24 11:00:00     1.225000
# 2017-08-24 12:00:00     3.497727
# 2017-08-24 13:00:00     5.989773
# 2017-08-24 14:00:00     5.212121
# 2017-08-24 15:00:00     4.014069
# 2017-08-24 16:00:00     2.749134
# 2017-08-24 17:00:00     5.400000
# 2017-08-24 18:00:00     7.550000
# 2017-08-24 19:00:00     9.518579
# 2017-08-24 20:00:00     5.663636
# 2017-08-24 21:00:00    13.353680
# 2017-08-24 22:00:00    30.317027
# 2017-08-24 23:00:00    22.128175
# 2017-08-25 00:00:00    23.333694
# 2017-08-25 01:00:00    14.188456
# 2017-08-25 02:00:00    11.468831
# 2017-08-25 03:00:00     9.053883
# 2017-08-25 04:00:00     4.487013
# 2017-08-25 05:00:00     0.615873
#                          ...
# 2017-08-29 18:00:00     3.349126
# 2017-08-29 19:00:00     0.711364
# 2017-08-29 20:00:00     5.654747
# 2017-08-29 21:00:00     2.690043
# 2017-08-29 22:00:00     6.075000
# 2017-08-29 23:00:00     6.857468
# 2017-08-30 00:00:00     4.952825
# 2017-08-30 01:00:00     3.522143
# 2017-08-30 02:00:00     1.289899
# 2017-08-30 03:00:00     2.475000
# 2017-08-30 04:00:00     1.037500
# 2017-08-30 05:00:00     1.625303
# 2017-08-30 06:00:00     1.175649
# 2017-08-30 07:00:00     0.580808
# 2017-08-30 08:00:00     1.344697
# 2017-08-30 09:00:00    -0.230303
# 2017-08-30 10:00:00     1.200649
# 2017-08-30 11:00:00     1.461508
# 2017-08-30 12:00:00     0.147619
# 2017-08-30 13:00:00     1.050000
# 2017-08-30 14:00:00     3.943182
# 2017-08-30 15:00:00     3.567652
# 2017-08-30 16:00:00    -0.166667
# 2017-08-30 17:00:00     1.686364
# 2017-08-30 18:00:00     0.648214
# 2017-08-30 19:00:00     2.085227
# 2017-08-30 20:00:00     5.885083
# 2017-08-30 21:00:00     0.806259
# 2017-08-30 22:00:00     3.081764
# 2017-08-30 23:00:00     6.282370
# Freq: H, Name: textblob_sent, Length: 168, dtype: float64

# %%
df_amznnews_dti_re.plot()

# %%
plt.bar(df_amznnews_dti_re.index, df_amznnews_dti_re)
# Out:
# <Container object of 168 artists>

# %%
# could play with rolling sentiment... mean? sum? other?
# df['100ma'] = df['Close'].rolling(window=100, min_periods=0).mean()

# %% [markdown]
# ###### Datetime and Graph issues...

# %%
# https://stackoverflow.com/questions/46376252/how-to-convert-list-of-numpy-datetime64-to-matplotlib-dates
# https://stackoverflow.com/questions/13703720/converting-between-datetime-timestamp-and-datetime64
# https://stackoverflow.com/questions/13703720/converting-between-datetime-timestamp-and-datetime64
plt_dates = mdates.date2num(list(df_amznnews.publish_time))

ax = sns.regplot(x=plt_dates, y='textblob_sent', data=df_amznnews,
                fit_reg=False)

# %%
df_amznnews.publish_time
# Out:
# 769   2017-08-24 00:04:00
# 336   2017-08-24 00:01:00
# 526   2017-08-24 00:03:00
# 690   2017-08-24 00:04:00
# 769   2017-08-24 00:04:00
# 858   2017-08-24 00:05:00
# 690   2017-08-24 00:04:00
# Name: publish_time, dtype: datetime64[ns]

# %%
array_dates = []
for x in df_amznnews.publish_time:
    y = np.datetime64(x)
    array_dates.append(y)

# %%
array_dates
# Out:
# [numpy.datetime64('2017-08-24T00:04:00.000000'),
#  numpy.datetime64('2017-08-24T00:01:00.000000'),
#  numpy.datetime64('2017-08-24T00:03:00.000000'),
#  numpy.datetime64('2017-08-24T00:04:00.000000'),
#  numpy.datetime64('2017-08-24T00:04:00.000000'),
#  numpy.datetime64('2017-08-24T00:05:00.000000'),
#  numpy.datetime64('2017-08-24T00:04:00.000000')]

# %%
np.array(array_dates)
# Out:
# array(['2017-08-24T00:04:00.000000', '2017-08-24T00:01:00.000000',
#        '2017-08-24T00:03:00.000000', '2017-08-24T00:04:00.000000',
#        '2017-08-24T00:04:00.000000', '2017-08-24T00:05:00.000000',
#        '2017-08-24T00:04:00.000000'], dtype='datetime64[us]')

# %%
x = np.array(array_dates).astype("M8[ms]").tolist()
y = df_amznnews.textblob_sent

plt.plot(x, y)
plt.xticks(rotation=45)
plt.show()

# %%
# https://stackoverflow.com/questions/1574088/plotting-time-in-python-with-matplotlib

dates = matplotlib.dates.date2num(list(df_amznnews.publish_time))
plt.xticks(rotation=45)
plt.tight_layout()
plt.plot_date(dates, df_amznnews.textblob_sent);

# %%
# https://stackoverflow.com/questions/9627686/plotting-dates-on-the-x-axis-with-pythons-matplotlib
import datetime as dt

# convert your strings to instances of Python datetime.date
dates = df_amznnews.publish_time.tolist()
x = [dt.datetime.strptime(d,'%m/%d/%Y').date() for d in dates]
y = range(len(x))

# then plot
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.plot(x,y)
plt.gcf().autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-0481ff9d360a> in <module>()
#       2
#       3 dates = df_amznnews.publish_time.tolist()
# ----> 4 x = [dt.datetime.strptime(d,'%m/%d/%Y').date() for d in dates]
#       5 y = range(len(x))
#       6
#
# <ipython-input-211-0481ff9d360a> in <listcomp>(.0)
#       2
#       3 dates = df_amznnews.publish_time.tolist()
# ----> 4 x = [dt.datetime.strptime(d,'%m/%d/%Y').date() for d in dates]
#       5 y = range(len(x))
#       6
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %% [markdown]
# ### Sentiment in Stock Market

# %% [markdown]
# #### Load ticker data

# %%
df_tick = pd.read_pickle('tweet_data/amzn_ohlcv_may18.pkl')
df_tick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4632 entries, 2000-01-03 to 2018-05-31
# Data columns (total 5 columns):
# 1. open      4632 non-null float64
# 2. high      4632 non-null float64
# 3. low       4632 non-null float64
# 4. close     4632 non-null float64
# 5. volume    4632 non-null float64
# dtypes: float64(5)
# memory usage: 217.1+ KB

# %%
# set index to datetime index
df_tick.set_index(df_tick.index.to_datetime(), inplace=True)
df_tick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4632 entries, 2000-01-03 to 2018-05-31
# Data columns (total 5 columns):
# 1. open      4632 non-null float64
# 2. high      4632 non-null float64
# 3. low       4632 non-null float64
# 4. close     4632 non-null float64
# 5. volume    4632 non-null float64
# dtypes: float64(5)
# memory usage: 217.1 KB
# /Users/jas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)

# %%
df_tick['4. close'][0:10]
# Out:
# 2017-08-24    952.45
# 2017-08-25    945.26
# 2017-08-28    946.02
# 2017-08-29    954.06
# 2017-08-30    967.59
# Name: 4. close, dtype: float64

# %%
# reduce graph data size
df_tick = df_tick.loc['2017-08-24':'2017-08-30']

# %% [markdown]
# #### ticker graph

# %%
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)
# ax1 = plt.xticks(rotation=45)

ax1.plot(df_tick.index, df_tick['4. close'])
# ax1.plot(df_tick.index, df_tick['100ma'])
ax2.bar(df_tick.index, df_tick['5. volume'])

plt.show()

# %% [markdown]
# #### Ticker + Sentiment Graph

# %% [markdown]
# **graph along with sentiment**
# - aggregate sentiment data by DAY
# - add sentiment data to 'df_tick' dataframe
# - plug it in for volume

# %% [markdown]
# **add amzn article sentiment for week to ticker close data... **
# #(1) downsample sentiment data on daily basis (many ways to do this...)
# #(2) plug into 'df_tick'
#
# Lots to play with on the sentiment data to make it 'intelligable':
# - take log of sum of data... results in range of sentiment scores of 3-5.
# - normalize the sum of the data... This one has intuitive promise <<<<
# - take the mean of the data
# - median of data doesn't do too much
# - remove all nuetral scores... (have plenty of sentiments to play with to remove these, which are at least half)

# %%
# build new df from 'df_amznnews' so as to leave that available for other play.
df_amznnews_2tick = df_amznnews[['publish_time','textblob_sent', 'vs_compound']]
# set index as datetimeindex
df_amznnews_2tick = df_amznnews.set_index('publish_time')
# resample to align with ticker data
df_amznnews_2tick = df_amznnews_2tick[['textblob_sent', 'vs_compound']].resample('1D').mean()
# result?
print(df_amznnews_2tick)
# print()
# print(np.log(df_amznnews_2tick))

# Normalize entire df: df_norm = (df - df.mean()) / (df.max() - df.min())
# Out:
#               textblob_sent  vs_compound
# publish_time
# 2017-08-24         0.117431     0.195959
# 2017-08-25         0.116186     0.077113
# 2017-08-26         0.097682     0.081416
# 2017-08-27         0.078457     0.089842
# 2017-08-28         0.163032     0.140102
# 2017-08-29         0.118615     0.087686
# 2017-08-30         0.065327     0.122651

# %%
# plug in to df_tick
df_tick_sent = df_tick.join(df_amznnews_2tick)

# %%
df_tick_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2017-08-24 to 2017-08-30
# Data columns (total 7 columns):
# 1. open          5 non-null float64
# 2. high          5 non-null float64
# 3. low           5 non-null float64
# 4. close         5 non-null float64
# 5. volume        5 non-null float64
# textblob_sent    5 non-null float64
# vs_compound      5 non-null float64
# dtypes: float64(7)
# memory usage: 480.0 bytes

# %%
# now the graph...
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
plt.title('Sentiment and Stock Price')
plt.ylabel('$USD/share')
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

plt.xticks(rotation=45)
plt.xlabel('Date')

ax1.plot(df_tick_sent.index, df_tick_sent['4. close'])
# ax1.plot(df_tick.index, df_tick['100ma'])
ax2.bar(df_tick_sent.index, df_tick_sent['textblob_sent'])

plt.savefig('Visuals/stockvsent.png', dpi=900, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Correlation

# %%
# Correlation??
df_tick_sent.corr()
# Out:
#                 1. open   2. high    3. low  4. close  5. volume  \
# 1. open        1.000000  0.648292  0.684662  0.295109   0.498413
# 2. high        0.648292  1.000000  0.875160  0.898814   0.054975
# 3. low         0.684662  0.875160  1.000000  0.698816  -0.191803
# 4. close       0.295109  0.898814  0.698816  1.000000  -0.066371
# 5. volume      0.498413  0.054975 -0.191803 -0.066371   1.000000
# textblob_sent -0.542785 -0.948420 -0.714574 -0.858167  -0.089273
# vs_compound    0.355626  0.053369  0.015079  0.089688   0.688872
#
#                textblob_sent  vs_compound
# 1. open            -0.542785     0.355626
# 2. high            -0.948420     0.053369
# 3. low             -0.714574     0.015079
# 4. close           -0.858167     0.089688
# 5. volume          -0.089273     0.688872
# textblob_sent       1.000000     0.125917
# vs_compound         0.125917     1.000000

# %% [markdown]
# ### Sentiment of Classified articles in Stock Market (Classification)

# %% [markdown]
# #### Load in labeled and prepared econ data...

# %%
df_econ = pd.read_csv('~/ds/data/nlp/Full-Economic-News-DFE-839861.csv', encoding='latin-1')
df_econ = df_econ[['relevance','headline']]
df_econ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 2 columns):
# relevance    8000 non-null object
# headline     8000 non-null object
# dtypes: object(2)
# memory usage: 125.1+ KB

# %% [markdown]
# #### Train the data on labeled econ articles

# %%
# set the target
X = df_econ.headline
y = df_econ.relevance

# split train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=53)

# vectorize the text (ensure ONLY the text)
count_vectorizer = CountVectorizer(stop_words='english')
count_train = count_vectorizer.fit_transform(X_train)

# make sure to ONLY transform the test data
count_test = count_vectorizer.transform(X_test)
print(count_vectorizer.get_feature_names()[1000:1010])
# Out:
# ['boosted', 'boosts', 'boot', 'booth', 'border', 'bored', 'born', 'borrow', 'borrowed', 'borrowers']

# %%
# test classification on econ docs
# instantiate the classifier
nb_classifier = MultinomialNB()

# fit the classifer to the training data
nb_classifier.fit(count_train, y_train)

# make prediction on transformed test data
pred = nb_classifier.predict(count_test)

# generate output of accuracy
metrics.accuracy_score(y_test, pred)
# Out:
# 0.7965909090909091

# %% [markdown]
# #### Train AMZN Articles data ('df_amznnews')

# %%
# make sure classifying on cleaned article titles

# %%
# df_amznnews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6459 entries, 769 to 1397573
# Data columns (total 10 columns):
# publish_time     6459 non-null datetime64[ns]
# feed_code        6459 non-null object
# source_url       6459 non-null object
# headline_text    6459 non-null object
# textblob_sent    6459 non-null float64
# vader_sent       6459 non-null object
# vs_neg           6459 non-null float64
# vs_neu           6459 non-null float64
# vs_pos           6459 non-null float64
# vs_compound      6459 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 715.1+ KB

# %%
# Vectorize the articles into a matrix
amznnews_matrix = count_vectorizer.transform(df_amznnews.headline_text)

# predict whether or not economically relevant based on previously fit model
amznnews_pred = nb_classifier.predict(amznnews_matrix)

# %%
# this returns a list of the indices where the tweet is related to economics
yes_ind = []
for ind, title in enumerate(amznnews_pred):
    if title == 'yes':
        yes_ind.append(ind)

# random sample to visually confirm...
print(yes_ind[5:10])
print(len(yes_ind))
# Out:
# [155, 156, 166, 180, 195]
# 218

# %% [markdown]
# Here could stop and use various methods to explore the difference between the 'yes' and 'no' economically 'relevant' articles (later)
# - 218 of the articles are classified as 'economically relevant' (could improve by ensuring evenly distributed classification of articles, or try other models...)

# %%
# below I want the entire DF but it has DT index, not numbered index... maybe with iloc???
# df_amznnews_clsfd = [df_amznnews.isin()]

df_amznnews_clsfd = df_amznnews.iloc[yes_ind]
df_amznnews_clsfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218 entries, 381028 to 1130261
# Data columns (total 10 columns):
# publish_time     218 non-null datetime64[ns]
# feed_code        218 non-null object
# source_url       218 non-null object
# headline_text    218 non-null object
# textblob_sent    218 non-null float64
# vader_sent       218 non-null object
# vs_neg           218 non-null float64
# vs_neu           218 non-null float64
# vs_pos           218 non-null float64
# vs_compound      218 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 18.7+ KB

# %%
# df_amznnews_clsfd.sample(10)

# %% [markdown]
# ### Stock+(Classified)Sentiment

# %%
print(df_amznnews_clsfd.info())
print()
print(df_tick.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218 entries, 381028 to 1130261
# Data columns (total 10 columns):
# publish_time     218 non-null datetime64[ns]
# feed_code        218 non-null object
# source_url       218 non-null object
# headline_text    218 non-null object
# textblob_sent    218 non-null float64
# vader_sent       218 non-null object
# vs_neg           218 non-null float64
# vs_neu           218 non-null float64
# vs_pos           218 non-null float64
# vs_compound      218 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 18.7+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2017-08-24 to 2017-08-30
# Data columns (total 5 columns):
# 1. open      5 non-null float64
# 2. high      5 non-null float64
# 3. low       5 non-null float64
# 4. close     5 non-null float64
# 5. volume    5 non-null float64
# dtypes: float64(5)
# memory usage: 400.0 bytes
# None

# %%
# build new df from 'df_amznnews' so as to leave that available for other play.
df_amznnews_clsfd_2tick = df_amznnews_clsfd[['publish_time','textblob_sent', 'vs_compound']]
df_amznnews_clsfd_2tick.head()
# Out:
#               publish_time  textblob_sent  vs_compound
# 381028 2017-08-25 15:13:00            0.0       0.1779
# 381377 2017-08-25 15:15:00            0.0       0.1779
# 733    2017-08-24 00:04:00            0.0       0.1779
# 9551   2017-08-24 00:56:00            0.2       0.1779
# 16393  2017-08-24 01:35:00            0.2       0.1779

# %%
# set index as datetimeindex
df_amznnews_clsfd_2tick = df_amznnews_clsfd_2tick.set_index('publish_time')
df_amznnews_clsfd_2tick.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 218 entries, 2017-08-25 15:13:00 to 2017-08-29 16:42:00
# Data columns (total 2 columns):
# textblob_sent    218 non-null float64
# vs_compound      218 non-null float64
# dtypes: float64(2)
# memory usage: 5.1 KB

# %%
# resample to align with ticker data
df_amznnews_clsfd_2tick = df_amznnews_clsfd_2tick[['textblob_sent', 'vs_compound']].resample('1D').mean()
# result?
print(df_amznnews_clsfd_2tick)
# print()
# print(np.log(df_amznnews_clsfd_2tick))
# Out:
#               textblob_sent  vs_compound
# publish_time
# 2017-08-24         0.040221     0.174324
# 2017-08-25         0.022069     0.075840
# 2017-08-26         0.026190     0.128229
# 2017-08-27         0.042031     0.156500
# 2017-08-28         0.186635     0.220628
# 2017-08-29         0.059202     0.023010
# 2017-08-30         0.030994     0.075432

# %%
# plug in to df_tick
df_tick_clsfd_sent = df_tick.join(df_amznnews_clsfd_2tick)
df_tick_clsfd_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2017-08-24 to 2017-08-30
# Data columns (total 7 columns):
# 1. open          5 non-null float64
# 2. high          5 non-null float64
# 3. low           5 non-null float64
# 4. close         5 non-null float64
# 5. volume        5 non-null float64
# textblob_sent    5 non-null float64
# vs_compound      5 non-null float64
# dtypes: float64(7)
# memory usage: 480.0 bytes

# %%
# now the graph...
ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
plt.title('Sentiment and Stock Price')
plt.ylabel('$USD/share')
ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

plt.xticks(rotation=45)
plt.xlabel('Date')

ax1.plot(df_tick_clsfd_sent.index, df_tick_clsfd_sent['4. close'])
# ax1.plot(df_tick.index, df_tick['100ma'])
ax2.bar(df_tick_clsfd_sent.index, df_tick_clsfd_sent['textblob_sent'])

plt.savefig('Visuals/stockvsent_cld.png', dpi=900, bbox_inches='tight')
plt.show()

# %%
df_corr = pd.DataFrame({'daily_price_change': [-7.19, 0.76, 8.02, 13.53], 'tbsent': [0.1174, .1162, .1630, 1186], 
                        'tbsent_class': [.0402, 0.02207, 0.1867, 0.0592]})

df_corr.corr()
# Out:
#                     daily_price_change    tbsent  tbsent_class
# daily_price_change            1.000000  0.722986      0.427640
# tbsent                        0.722986  1.000000     -0.159286
# tbsent_class                  0.427640 -0.159286      1.000000

# %% [markdown]
#    textblob_sent  vs_compound
# publish_time
# 2017-08-24         0.117431     0.195959
# 2017-08-25         0.116186     0.077113
# 2017-08-26         0.097682     0.081416
# 2017-08-27         0.078457     0.089842
# 2017-08-28         0.163032     0.140102
# 2017-08-29         0.118615     0.087686
# 2017-08-30         0.065327     0.122651

# %%
df_tick_clsfd_sent
# Out:
#             1. open  2. high    3. low  4. close  5. volume  textblob_sent  \
# 2017-08-24   957.42  959.000  941.1400    952.45  5086748.0       0.040221
# 2017-08-25   956.00  957.621  944.1000    945.26  3292776.0       0.022069
# 2017-08-28   946.54  953.000  942.2500    946.02  2529087.0       0.186635
# 2017-08-29   940.00  956.000  936.3300    954.06  2853972.0       0.059202
# 2017-08-30   958.44  969.410  956.9062    967.59  2860718.0       0.030994
#
#             vs_compound
# 2017-08-24     0.174324
# 2017-08-25     0.075840
# 2017-08-28     0.220628
# 2017-08-29     0.023010
# 2017-08-30     0.075432

# %%
# correlation
df_tick_clsfd_sent.corr()
# Out:
#                 1. open   2. high    3. low  4. close  5. volume  \
# 1. open        1.000000  0.648292  0.684662  0.295109   0.498413
# 2. high        0.648292  1.000000  0.875160  0.898814   0.054975
# 3. low         0.684662  0.875160  1.000000  0.698816  -0.191803
# 4. close       0.295109  0.898814  0.698816  1.000000  -0.066371
# 5. volume      0.498413  0.054975 -0.191803 -0.066371   1.000000
# textblob_sent -0.509622 -0.595910 -0.260140 -0.412888  -0.434904
# vs_compound    0.166664 -0.354617 -0.065321 -0.392118   0.252006
#
#                textblob_sent  vs_compound
# 1. open            -0.509622     0.166664
# 2. high            -0.595910    -0.354617
# 3. low             -0.260140    -0.065321
# 4. close           -0.412888    -0.392118
# 5. volume          -0.434904     0.252006
# textblob_sent       1.000000     0.680655
# vs_compound         0.680655     1.000000

# %%
# manual correlation test
df_corr = pd.DataFrame({'daily_price_change': [-7.19, 0.76, 8.02, 13.53], 'tbsent': [0.1174, .1162, .1630, 1186], 
                        'tbsent_class': [.0402, 0.02207, 0.1867, 0.0592]})

df_corr.corr()

# %% [markdown]
# ### Word Cloud

# %% [markdown]
# https://github.com/amueller/word_cloud

# %% [markdown]
# #### Article cloud

# %%
# from os import path
from wordcloud import WordCloud

# d = path.dirname(__file__)

# Read the whole text.
# text = open(path.join(d, 'constitution.txt')).read()
text = ' '.join(df_amznnews.headline_text)

# # Generate a word cloud image
# wordcloud = WordCloud().generate(text)

# # Display the generated image:
# # the matplotlib way:
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('Visuals/article_cloud.png', dpi=900, bbox_inches='tight')
# plt.show()

# %% [markdown]
# #### Twitter cloud

# %%
# from os import path
from wordcloud import WordCloud

# d = path.dirname(__file__)

# Read the whole text.
# text = open(path.join(d, 'constitution.txt')).read()
text = ' '.join(clean_list)

# # Generate a word cloud image
# wordcloud = WordCloud().generate(text)

# # Display the generated image:
# # the matplotlib way:
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure(figsize=(10,8)) #  dpi=200
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# plt.savefig('Visuals/twitter_cloud2.png', dpi=900, bbox_inches='tight'); # , bbox_inches='tight'
# plt.show()
# Out:
# (-0.5, 399.5, 199.5, -0.5)
